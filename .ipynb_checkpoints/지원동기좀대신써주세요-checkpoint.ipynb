# %%
from bs4 import BeautifulSoup
from downloads import *
import requests
import time
import urllib
import os
from nltk.probability import FreqDist
from NLP import * 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib 
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
font_setting()

# %%
q=input("지원하시는 회사의 이름을 기재해주세요\t")
q2=input("지원하는 회사의 직무를 기재해주세요\t")
p=int(input("몇 페이지까지 검색할까요?\t\t"))
q3=input("공고에 직무에 대한 설명이 있다면 키워드 중심으로 같이 써주세요(없을 시 공란으로 두세요)\t")
# Out:
# 지원하시는 회사의 이름을 기재해주세요	삼성생명
# 지원하는 회사의 직무를 기재해주세요	디지털
# 몇 페이지까지 검색할까요?		5
# 공고에 직무에 대한 설명이 있다면 키워드 중심으로 같이 써주세요(없을 시 공란으로 두세요)

# %%
news_list=[]
for page in range(1,p+1):
    url=download("https://search.daum.net/search",params={"w":"news","q":q+" "+q2,"cluster":"y","p":str(page)})
    dom=BeautifulSoup(url.text,"lxml")
    news_list+=[(_["href"], _.text) for _ in dom.select("article .wrap_tit.mg_tit a")]

# %%
# import re
# pattern=re.compile("text|article|txt|Article|News")
# if pattern.search("article"):print(1)

# %%
# dom.select("[class+{0}],[id+{0}]".format(re.compile("text|article|txt|Article|News")))

# %%
# dom.select("[id+{0}]".format(pattern))

# %%
# print([_.text for _ in dom.select("[class^={0}],[id^={0}]".format(pattern))])

# %% [markdown]
# ## 뉴스 솎기

# %%
news_list
# Out:
# [('https://cp.news.search.daum.net/p/79756322',
#   '[보험업무 RPA 시대-삼성생명]도입 6개월만에 안착 연 2만4000시간 ...'),
#  ('http://v.media.daum.net/v/20190417143329712?f=o',
#   '로봇에 업무 맡기니 2만 시간 절약..삼성생명의 디지털 혁신'),
#  ('https://cp.news.search.daum.net/p/79811253',
#   '"우리가 남이가?" 삼성생명, 삼성전자-제일기획 팔고 ‘삼성바이오...'),
#  ('http://v.media.daum.net/v/20190417101206118?f=o',
#   '삼성생명, RPA 정착으로 디지털혁신 가속화'),
#  ('https://cp.news.search.daum.net/p/78534934', '삼성생명 현성철號, 디지털혁신 성과 가시화'),
#  ('http://v.media.daum.net/v/20190417182112681?f=o',
#   '삼성생명, 로봇 프로세스 자동화로 업무시간 단축'),
#  ('http://v.media.daum.net/v/20190515092102660?f=o',
#   '삼성생명, 1분기 순익 4473억원..전년 대비 14.7%↑'),
#  ('http://v.media.daum.net/v/20190509083900768?f=o',
#   '삼성생명 "생명사랑 릴레이로 자살 예방 기부하세요"'),
#  ('https://cp.news.search.daum.net/p/78542156', '삼성생명, RPA 정착...연 2만4천시간 절약'),
#  ('http://v.media.daum.net/v/20190507103000743?f=o',
#   "삼성생명, 총 5000만원 상금 '제1회 전국 탁구클럽 대축제' 개최"),
#  ('https://cp.news.search.daum.net/p/78532522',
#   '삼성생명, ‘PRA 프로젝트’ 6개월...연간 2만4000시간 절약'),
#  ('https://cp.news.search.daum.net/p/78534409',
#   "삼성생명, 로봇 'RPA' 도입 반년 만에 연 2만4000시간 절약"),
#  ('http://v.media.daum.net/v/20190424060021137?f=o',
#   "[CEO가 뛴다-32] 현성철 삼성생명 사장, 글로벌 일류 도약 '5대 플..."),
#  ('https://cp.news.search.daum.net/p/78545533',
#   '\u200b삼성생명, 단순업무에 RPA 도입해 연간 2만 시간 절약'),
#  ('https://cp.news.search.daum.net/p/78529761', '삼성생명 "RPA 도입후 2만4000시간 절약"'),
#  ('http://v.media.daum.net/v/20190520103300854?f=o',
#   "우정사업본부, '우체국 뉴스룸24' 통해 국민과 친근한 소통"),
#  ('https://cp.news.search.daum.net/p/78557066',
#   '삼성생명 “RPA 도입 6개월만에 年 2만4000시간 절약”'),
#  ('http://v.media.daum.net/v/20190512104533601?f=o',
#   '보험의 디지털 혁신 만드는 디레몬.."마이데이터 시대 이끈다"'),
#  ('http://v.media.daum.net/v/20190417160528338?f=o',
#   '삼성생명 로봇 자동화 도입 6개월..연 2만4,000시간 절약'),
#  ('http://v.media.daum.net/v/20190417175704926?f=o',
#   '삼성생명, 업무자동화로 年 24,000시간 절약'),
#  ('http://v.media.daum.net/v/20190305113148200?f=o',
#   "삼성생명 '청소년 미술대회' 첫 디지털 심사"),
#  ('http://v.media.daum.net/v/20190508135613655?f=o',
#   '"삼성이 생각하는 디지털 전환은"..삼성SDS, 8년만에 대형 IT 콘퍼런스'),
#  ('https://cp.news.search.daum.net/p/79756321',
#   '[보험업무 RPA 시대]주 52시간제 발맞춰 보험사도 ‘RPA 시스템’으...'),
#  ('http://v.media.daum.net/v/20190516100024327?f=o',
#   '"약관 어렵게 써놓고 책임회피"..보험사 작심비판한 윤석헌'),
#  ('http://v.media.daum.net/v/20190518110204069?f=o',
#   "'개인 맞춤형' 헬스케어 서비스 늘리는 보험사들"),
#  ('http://v.media.daum.net/v/20190418093601837?f=o', '삼성생명, 보장금액 증액서비스 실시'),
#  ('https://cp.news.search.daum.net/p/79756125', "특집-업무 자동화 '바람'‧‧‧올해 더 거세다"),
#  ('https://cp.news.search.daum.net/p/77344479',
#   '내달 14일 삼성 GSAT ...삼성생명 등 금융계열사 디지털 금융직 눈길'),
#  ('https://cp.news.search.daum.net/p/79002479',
#   "주52시간제 두 달 남은 보험업계…'RPA'가 해답?"),
#  ('http://v.media.daum.net/v/20190513084804549?f=o',
#   "'변해야 산다' 보험 CEO '인슈어테크' 혁신 바람-로봇이 보험심사·..."),
#  ('http://v.media.daum.net/v/20190515113001532?f=o',
#   '보험사 해외 인수합병 확대 조건.."채권 등 자금조달 규제 완화해야"'),
#  ('http://v.media.daum.net/v/20190513104002038?f=o',
#   "원광디지털대, '술수학 포럼 2019' 개최"),
#  ('https://cp.news.search.daum.net/p/79640291',
#   '김정남 DB손해보험 사장 디지털 혁신…내년 1월부터 AI설계사 보험...'),
#  ('https://cp.news.search.daum.net/p/79739243',
#   '[부음] 백윤기 모친, 서민석 부친, 한효진 부친, 손권희'),
#  ('https://cp.news.search.daum.net/p/78269446', '삼성생명, 비대면 실명인증 서비스 도입'),
#  ('https://cp.news.search.daum.net/p/79635632',
#   "차남규·여승주 이끄는 한화생명, '생보 2위' 지위 '먹구름'"),
#  ('https://cp.news.search.daum.net/p/79743199',
#   '보험사들 저출산·저금리·규제 여파 순이익 급감, 1분기 순익 올해...'),
#  ('http://v.media.daum.net/v/20190322040617333?f=o',
#   '[미래금융] 삼성생명, 보험약관 문자로..AI챗봇이 대출상담'),
#  ('https://cp.news.search.daum.net/p/78844887',
#   'DB손보·KB손보·삼성생명…‘보험사 RPA 도입’ 기대와 우려'),
#  ('https://cp.news.search.daum.net/p/79499140', '보험·카드사도 로봇 바람…RPA 도입 박차'),
#  ('https://cp.news.search.daum.net/p/78816655',
#   "삼성전자, QLED 8K TV 삼성생명 '청소년 미술대회' 심사 활용"),
#  ('https://cp.news.search.daum.net/p/79801669',
#   '[금요칼럼] 스마트 서비스(Smart Service)로 초 연결(hyper-connect...'),
#  ('https://cp.news.search.daum.net/p/79477288',
#   '(대한민국 재벌 신뢰지수) KB국민은행, 2년 연속 신뢰하는 은행 1위'),
#  ('https://cp.news.search.daum.net/p/79655392',
#   '윤석헌 "국내 금융포용 미흡…분쟁 적극 대응"(종합)'),
#  ('http://v.media.daum.net/v/20190418171549209?f=o',
#   "보험사 취업, 직무이해 높고 '핀테크'까지 갖추면 금상첨화"),
#  ('https://cp.news.search.daum.net/p/79424938',
#   '[동국대·상생과통일포럼 리더십 최고위과정 8기 ⑩강] 박용진 “시...'),
#  ('https://cp.news.search.daum.net/p/79620058', '5월 15일 주요공시'),
#  ('https://cp.news.search.daum.net/p/79412924',
#   '[보험사 이모저모] "단순·반복 업무는 가라!"…RPA바람'),
#  ('http://v.media.daum.net/v/20190328170122630?f=o',
#   "[2019 대한민국 파워기업 50] 삼성생명, '혁신'으로 업계 불황 넘는다"),
#  ('https://cp.news.search.daum.net/p/77565139', '삼성생명, 새 먹거리 인슈어테크에 ‘통 큰 투자’')]

# %%
title=[title for link,title in news_list]

# %%
len(title)
# Out:
# 50

# %%
title=[title for link,title in news_list]
dist=[]
import textdistance
for i in range(len(title)):
    for _ in title[i:]:
        dist=textdistance.hamming.normalized_similarity(_,title[i])
        if dist>0.2 and dist<1:
            title[i]=np.nan
            break
# textdistance.hamming('text', 'test')
# textdistance.hamming.normalized_similarity('text', 'test')
# textdistance.hamming('arrow', 'arow')textdistance.hamming.normalized_similarity('arrow', 'arow')

# %%
news_list=pd.DataFrame({"title":title,"link":[link for link,_ in news_list]}).dropna().reset_index().drop("index",1)

# %%
# for link, title in news_list:
#     url = download(link)
#     dom = BeautifulSoup(url.text,"lxml")
#     if dom.select("#articletxt"): # 한국 경제
#         print([_.text for _ in dom.select("#articletxt")])
#     elif dom.select("#articleBody p"):# 아이뉴스 
#         print(dom.select("#articleBody p"))
#     elif dom.select("#divNewsContent"):
#         print([_.text for _ in dom.select("#divNewsContent")])
#     elif dom.select("#articleText"):
#         print([_.text for _ in dom.select("#articleText")]) # 헤럴드경제
#     elif dom.select("#articleBody"):
#         print([_.text for _ in dom.select("#articleBody")]) # 전자신문

# %% [markdown]
# ## 링크 타고들어가서 뉴스 가져오기

# %%
css_codes=["#articletxt","#articleBody p","#divNewsContent","#articleText","tbody b","#textBody","#news_body_area_contents"]

# %%
len(news_list)
# Out:
# 32

# %%
news_list["link"]
# Out:
# 0     http://v.media.daum.net/v/20190417143329712?f=o
# 1          https://cp.news.search.daum.net/p/79811253
# 2     http://v.media.daum.net/v/20190520103300854?f=o
# 3          https://cp.news.search.daum.net/p/78557066
# 4     http://v.media.daum.net/v/20190512104533601?f=o
# 5     http://v.media.daum.net/v/20190508135613655?f=o
# 6          https://cp.news.search.daum.net/p/79756321
# 7     http://v.media.daum.net/v/20190516100024327?f=o
# 8     http://v.media.daum.net/v/20190518110204069?f=o
# 9          https://cp.news.search.daum.net/p/79756125
# 10         https://cp.news.search.daum.net/p/77344479
# 11         https://cp.news.search.daum.net/p/79002479
# 12    http://v.media.daum.net/v/20190513084804549?f=o
# 13    http://v.media.daum.net/v/20190515113001532?f=o
# 14    http://v.media.daum.net/v/20190513104002038?f=o
# 15         https://cp.news.search.daum.net/p/79640291
# 16         https://cp.news.search.daum.net/p/79739243
# 17         https://cp.news.search.daum.net/p/79635632
# 18         https://cp.news.search.daum.net/p/79743199
# 19    http://v.media.daum.net/v/20190322040617333?f=o
# 20         https://cp.news.search.daum.net/p/78844887
# 21         https://cp.news.search.daum.net/p/79499140
# 22         https://cp.news.search.daum.net/p/78816655
# 23         https://cp.news.search.daum.net/p/79801669
# 24         https://cp.news.search.daum.net/p/79477288
# 25         https://cp.news.search.daum.net/p/79655392
# 26    http://v.media.daum.net/v/20190418171549209?f=o
# 27         https://cp.news.search.daum.net/p/79424938
# 28         https://cp.news.search.daum.net/p/79620058
# 29         https://cp.news.search.daum.net/p/79412924
# 30    http://v.media.daum.net/v/20190328170122630?f=o
# 31         https://cp.news.search.daum.net/p/77565139
# Name: link, dtype: object

# %%
daum=BeautifulSoup(download(news_list["link"][1]).text,"lxml")

# %%
daum.select()
# Out:
# [<tbody><tr>
#  <td colspan="5" style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 713pt; height: 16pt;text-align :center;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 11.9pt;letter-spacing: -0.4pt;line-height: 18.2pt;color: #000000"></span><span style="font-size: 11.9pt;letter-spacing: -0.4pt;line-height: 18.2pt;color: #000000">&lt;삼성생명 특별계정 소유주식 변동 현황&gt;</span></td>
#  </tr>
#  <tr>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-left-style:none;border-right-style:none; width: 94pt; height: 14pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 10.2pt;letter-spacing: -0.4pt;line-height: 15.6pt;color: #000000"></span><span style="font-size: 10.2pt;letter-spacing: -0.4pt;line-height: 15.6pt;color: #1F487D">종목명</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-left-style:none;border-right-style:none; width: 220pt; height: 14pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 10.2pt;letter-spacing: -0.4pt;line-height: 15.6pt;color: #000000"></span><span style="font-size: 10.2pt;letter-spacing: -0.4pt;line-height: 15.6pt;color: #1F487D">변경 전 주식 수(시기)</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-left-style:none;border-right-style:none; width: 166pt; height: 14pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 10.2pt;letter-spacing: -0.4pt;line-height: 15.6pt;color: #000000"></span><span style="font-size: 10.2pt;letter-spacing: -0.4pt;line-height: 15.6pt;color: #1F487D">변경 후 주식 수(시기)</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-left-style:none;border-right-style:none; width: 92pt; height: 14pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 10.2pt;letter-spacing: -0.4pt;line-height: 15.6pt;color: #000000"></span><span style="font-size: 10.2pt;letter-spacing: -0.4pt;line-height: 15.6pt;color: #1F487D">수량</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-left-style:none;border-right-style:none; width: 141pt; height: 14pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 10.2pt;letter-spacing: -0.4pt;line-height: 15.6pt;color: #000000"></span><span style="font-size: 10.2pt;letter-spacing: -0.4pt;line-height: 15.6pt;color: #1F487D">연초 이후 주가 추이</span></td>
#  </tr>
#  <tr>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 94pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">삼성전자</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 220pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">1835만1459주(4/24)</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 166pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">1829만3102주(5/15)</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 92pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">5만8357주 순매도</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 141pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">-6.15%</span></td>
#  </tr>
#  <tr>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 94pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">제일기획</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 220pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">19만2509주(4/2)</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 166pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">17만2950주(5/17)</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 92pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">1만9559주 순매도</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 141pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">15.47%</span></td>
#  </tr>
#  <tr>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 94pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">삼성바이오로직스</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 220pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">5만4414주(3/25)</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 166pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">5만5669주(4/25)</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 92pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">1255주 순매수</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 141pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">-21.52%</span></td>
#  </tr>
#  <tr>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 94pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">삼성증권</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 220pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">2636만6300주(4/5)</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 166pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">2636만6452주(5/17)</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 92pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">152주 순매수</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 141pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">10.24%</span></td>
#  </tr>
#  <tr>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 94pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">삼성화재</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 220pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">711만6349주(4/5)</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 166pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">711만7118주(5/17)</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 92pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">769주 순매수</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 141pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">4.73%</span></td>
#  </tr>
#  <tr>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 94pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">삼성카드</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 220pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">8327만5984주(4/5)</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 166pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">8327만6206주(5/17)</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 92pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">222주 순매수</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 141pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">3.75%</span></td>
#  </tr>
#  </tbody>]

# %%
daum.select("div")
# Out:
# [<div id="wrap">
#  <!--상단영역-->
#  <div id="header">
#  <div class="layout_header">
#  <!-- hline1_area -->
#  <div class="hline1_area">
#  <div class="head_line1">
#  <!-- left_area -->
#  <div class="left_area">
#  <div id="Top_Mark">
#  <ul>
#  <!--li class="home"><a href="#" onClick="this.style.behavior='url(#default#homepage)';this.setHomePage('http://www.ekn.kr');">시작페이지</a></li-->
#  <li class="mark"><a href="#" onclick="window.external.AddFavorite('http://www.ekn.kr', '에너지경제신문')">즐겨찾기 추가</a></li>
#  <!-- <li class="update test"></li> -->
#  <li class="update">2019년 05월 21일 14시 56분</li>
#  </ul>
#  </div>
#  </div>
#  <!-- //left_area -->
#  <!-- right_area -->
#  <div class="right_area">
#  <ul>
#  <li><a href="/">홈</a>|</li>
#  <li><a href="javascript:doPopup('/news/request_form.html?mode=report', 600, 600, 'yes')">기사제보</a>|</li>
#  <li><a href="/member/member_login.html"> <img alt="로그인" src="/data/skin/layout/1/m01/images/header/btn_login.gif"/></a></li>
#  <li><a href="/member/member_join.html"> <img alt="회원가입" src="/data/skin/layout/1/m01/images/header/btn_membership.gif"/></a></li>
#  </ul>
#  </div>
#  <!-- //right_area -->
#  </div>
#  </div>
#  <!-- //hline1_area -->
#  <!-- hline2_area -->
#  <div class="hline2_area">
#  <div class="head_line2">
#  <h1 class="logo"><a href="/" onfocus="blur()" target="_top"><img alt="에너지경제신문" class="png24" height="93" src="/data/design/logo/toplogo_20180618113344.png" width="317"/></a></h1>
#  <div class="left_bnr"><div style="padding-bottom:10px;text-align:center;"><a href="http://www.ekn.kr/news/banner_click.php?no=537" target="_blank"><img alt="배너" border="0" height="100" src="/data/banner/banner_1555291369.jpg" width="250"/></a></div></div>
#  <div class="right_bnr" style="bottom:13px; "><div style="padding-bottom:1px;text-align:center;"><a href="http://www.ekn.kr/news/banner_click.php?no=397" target="_blank"><img alt="배너" border="0" height="100" src="/data/banner/banner_1558392167.jpg" width="250"/></a></div></div>
#  </div>
#  </div>
#  <!-- //hline2_area -->
#  <!-- hline3_area -->
#  <div class="hline3_area">
#  <div class="head_line3">
#  <div class="gnb01">
#  <ul>
#  <li><a href="http://www.ekn.kr/">
#  <img alt="뉴스 홈" class="menuitem" id="menu1" src="/data/menu/1/menu_55.jpg" width="80"/>
#  </a></li>
#  <li><a href="/news/section_list_all.html?sec_no=130">
#  <img alt="경제" class="menuitem" id="menu2" src="/data/menu/1/menu_8.jpg" width="56"/>
#  </a></li>
#  <li><a href="/news/section_list_all.html?sec_no=221">
#  <img alt="증권·금융" class="menuitem" id="menu3" src="/data/menu/1/menu_59.jpg" width="96"/>
#  </a></li>
#  <li><a href="/news/section_list_all.html?sec_no=228">
#  <img alt="부동산" class="menuitem" id="menu4" src="/data/menu/1/menu_60.jpg" width="79"/>
#  </a></li>
#  <li><a href="/news/section_list_all.html?sec_no=123">
#  <img alt="기업 &amp; Biz" class="menuitem" id="menu5" src="/data/menu/1/menu_3.jpg" width="100"/>
#  </a></li>
#  <li><a href="/news/section_list_all.html?sec_no=56">
#  <img alt="에너지" class="menuitem" id="menu6" src="/data/menu/1/menu_31.jpg" width="79"/>
#  </a></li>
#  <li><a href="/news/section_list_all.html?sec_no=25">
#  <img alt="정치 · 사회" class="menuitem" id="menu7" src="/data/menu/1/menu_61.jpg" width="96"/>
#  </a></li>
#  <li><a href="/news/section_list_all.html?sec_no=74">
#  <img alt="오피니언" class="menuitem" id="menu8" src="/data/menu/1/menu_32.jpg" width="90"/>
#  </a></li>
#  <li><a href="/news/section_list_all.html?sec_no=236">
#  <img alt="Visual" class="menuitem" id="menu9" src="/data/menu/1/menu_34.jpg" width="76"/>
#  </a></li>
#  <li><a href="/news/section_list_all.html?sec_no=280">
#  <img alt="YOLO" class="menuitem" id="menu10" src="/data/menu/1/menu_2.jpg" width="76"/>
#  </a></li>
#  </ul>
#  </div>
#  <div class="search0" style="padding-bottom:5px; float:right;">
#  <div id="SearchForm">
#  <fieldset>
#  <form action="/news/search_result.html" id="topSearchForm" method="post" name="topSearchForm">
#  <input name="sc_area" type="hidden" value="A"/>
#  <input name="view_type" type="hidden" value="sm"/>
#  <input class="inptxt" id="searchWord" maxlength="255" name="searchWord" onclick="setSearchBox(1);" onfocus="this.value='';" value="검색 할 기사를 입력하세요."/>
#  <input id="Search2" maxlength="255" name="sc_word" onkeydown="if(event.keyCode==13){SearchCheck();}" style="display:none;"/>
#  <input alt="검색" class="btn_search" height="26" src="/data/skin/layout/1/m01/images/header/btn_search1.gif" style="float: right;" type="image" width="40"/>
#  <button onclick="SearchCheck();setSearchBox(1);" title="기사검색">기사검색</button>
#  </form>
#  </fieldset>
#  </div>
#  </div>
#  <!-- 중분류 -->
#  <div class="gnb02" style="margin-top:-5px;">
#  <div id="real_time_box">
#  <ul id="real_time_list"></ul>
#  </div>
#  <div class="smenuitem" id="submenu2" style="display:none; position:relative; bottom:0px;  padding-left:20px;">
#  <a href="/news/section.html?sec_no=258">경제일반</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=132">금융정책</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=223">국제경제·국제금융</a> </div>
#  <div class="smenuitem" id="submenu3" style="display:none; position:relative; bottom:0px;  padding-left:30px;">
#  <a href="/news/section.html?sec_no=224">투자전략·재테크</a><span class="lnb_line"> |</span> <a href="http://www.ekn.kr/news/biz.html?sec_no=262">인베스트플러스+</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=225">공시</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=226">특징주</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=241">증권일반</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=227">은행</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=242">보험</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=243">제2금융</a> </div>
#  <div class="smenuitem" id="submenu4" style="display:none; position:relative; bottom:0px;  padding-left:170px;">
#  <a href="/news/section.html?sec_no=245">건설업계</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=230">아파트·주택</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=231">분양·청약</a> </div>
#  <div class="smenuitem" id="submenu5" style="display:none; position:relative; bottom:0px;  padding-left:80px;">
#  <a href="/news/section.html?sec_no=232">재계</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=127">전자·IT</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=233">통신·방송·게임</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=184">자동차</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=124">조선·해운·항공</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=268">철강·기계·산전</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=269">석화·정유</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=126">유통·광고</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=155">제약·바이오</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=204">중기·벤처</a> </div>
#  <div class="smenuitem" id="submenu6" style="display:none; position:relative; bottom:0px;  padding-left:160px;">
#  <a href="/news/section.html?sec_no=57">에너지정책</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=59">전력·원자력</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=61">석유·가스</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=201">전지·태양광</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=62">자원·원자재</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=58">신재생</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=183">환경·기후·온실</a> </div>
#  <div class="smenuitem" id="submenu7" style="display:none; position:relative; bottom:0px;  padding-left:490px;">
#  <a href="/news/section.html?sec_no=96">정치</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=66">정책</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=36">사회</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=270">교육</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=259">전국</a> </div>
#  <div class="smenuitem" id="submenu8" style="display:none; position:relative; bottom:0px;  padding-left:400px;">
#  <a href="/news/section.html?sec_no=76">칼럼</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=77">전문가 기고</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=153">데스크칼럼</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=78">기자의 눈</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=180">파워인터뷰</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=181">인사·부고·동정</a> </div>
#  <div class="smenuitem" id="submenu9" style="display:none; position:relative; bottom:0px;  padding-left:500px;">
#  <a href="/news/section.html?sec_no=248">카드뉴스</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=250">스포테인먼트</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=251">에경TV</a> </div>
#  <div class="smenuitem" id="submenu10" style="display:none; position:relative; bottom:0px;  padding-left:600px;">
#  <a href="/news/section.html?sec_no=281">국내여행</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=282">해외여행</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=283">골프</a><span class="lnb_line"> |</span> <a href="/news/section.html?sec_no=284">뉴스클립</a> </div>
#  <a href="http://www.facebook.com/eknnews" target="_blank"><img onmouseout="kill();" onmouseover="popup('에너지경제 페이스북 페이지 보기','#FFFFCC');" src="/images/sns/btn_fb2.png" style="border: 0; float:right; height:28px; top:0px; margin-right:10px;"/></a>
#  <a href="http://www.twitter.com/ekneenews" target="_blank"><img onmouseout="kill();" onmouseover="popup('에너지경제 트위터 페이지 보기','#FFFFCC');" src="/images/sns/btn_tw2.png" style="border: 0; float:right; height:28px; margin-right:0px;"/></a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <script type="text/javascript">
#  function blockUiCall()
#  {
#  	$.blockUI({
#          message: '<h1 style="font-size: 29px;">Please wait.</h1>',
#          css: {
#              border: 'none',
#              padding: '15px',
#              backgroundColor: '#000',
#              '-webkit-border-radius': '10px',
#              '-moz-border-radius': '10px',
#              opacity: .5,
#              color: '#fff'
#              }
#      });
#  }
#
#  function unblockUiCall()
#  {
#  	$.unblockUI();
#  }
#
#  var menuimages = [
#  			'/data/menu/1/menu_55.jpg','/data/menu/1/menu_on_55.jpg'
#  			,'/data/menu/1/menu_8.jpg','/data/menu/1/menu_on_8.jpg'
#  			,'/data/menu/1/menu_59.jpg','/data/menu/1/menu_on_59.jpg'
#  			,'/data/menu/1/menu_60.jpg','/data/menu/1/menu_on_60.jpg'
#  			,'/data/menu/1/menu_3.jpg','/data/menu/1/menu_on_3.jpg'
#  			,'/data/menu/1/menu_31.jpg','/data/menu/1/menu_on_31.jpg'
#  			,'/data/menu/1/menu_61.jpg','/data/menu/1/menu_on_61.jpg'
#  			,'/data/menu/1/menu_32.jpg','/data/menu/1/menu_on_32.jpg'
#  			,'/data/menu/1/menu_34.jpg','/data/menu/1/menu_on_34.jpg'
#  			,'/data/menu/1/menu_2.jpg','/data/menu/1/menu_on_2.jpg'
#  		];
#
#  $(function(){
#  	/* $.post("/api/last_edit", "", function(response){
#  		$("#Top_Mark ul .update").html("<strong class='test'>UPDATE</strong> : " + response);
#  		console.log("날짜 : "+ response)
#  	}); */
#  	// 20171121 cs9743, 속보 카테고리 데이터, 서인선
#  	$.post("/iframe/real_time.php", function(data){
#  		$(data).each(function(key, value){
#  			$("#real_time_list").append("<li><a href='" + value.link + "'><span class='clock'>" + value.date_diff + "</span>" + value.title + "</a></li>");
#  		});
#
#  		var nt_example1 = $('#real_time_list').newsTicker({
#  		    row_height: 29,
#  		    max_rows: 3,
#  		    duration: 4000
#  		});
#  	}, "json");
#
#  	/* $.post("/api/getHeadSession", '', function(response){
#  		$("#login_base").html(response);
#  		$("#jebo_button").click(function(){
#  			doPopup("/news/request_form.html?mode=report", 600, 600, 'yes')
#  		});
#  	}); */
#
#  	$(".zeta-menu > li").mouseenter(function(){
#  		//현재 li 좌측 넓이
#  		var liLeftW = 0;
#  		for(i=0; i <= $(this).index(); i++){
#  			liLeftW = liLeftW + $(".zeta-menu > li").eq(i).width();
#  		}
#
#  		//서브메뉴 ui 넓이
#  		var subMenuW = 0;
#  		$("ul > li", this).each(function(){
#  			subMenuW = subMenuW + $(this).width()+2;
#  		});
#  		$("ul", this).width(subMenuW);
#
#  		//zeta-menu 넓이 넘을 시
#  		var currentLiW = $(this).width();
#  		var remainVal = $(".zeta-menu").width() - (subMenuW + liLeftW - currentLiW);
#  		if( remainVal < 0 ){
#  			$("ul", this).css({left:remainVal});
#  		}
#  	});
#
#  	$(".zeta-menu > li:not(:first-child)").mouseenter(function(){
#  		$("#real_time_list, #sns_icon").hide();
#  	}).mouseleave(function(){
#  		$("#real_time_list, #sns_icon").show();
#  	});
#
#
#
#  	$('.menuitem').mouseover(function() {
#  		resetMenuOver();
#  		hideSubMenus();
#
#  		try {
#  			var idValue = $(this).attr('id');
#  			if (idValue == null || idValue.length <= 4) {
#  				return;
#  			}
#
#  			var idxNo = idValue.substring(4);
#
#  			$('#submenu'+idxNo).css('display', 'inline');
#  			setMenuOver(idxNo);
#  		} catch (e) {
#  		}
#  	});
#
#  	$('.smenuitem').mouseleave(function() {
#  		$(".smenuitem").css('display', 'none');
#  		$("#real_time_box").css('display', 'block');
#  	});
#
#  	showSubMenu = function(idxNo) {
#  		try {
#
#  			$('#submenu'+idxNo).css('display', 'inline');
#
#  		} catch (e) {
#  		}
#  	};
#
#  	setMenuOver = function(idxNo) {
#  		try {
#  			var overImage = menuimages[((idxNo - 1) * 2 + 1)];
#  			$('#menu'+idxNo).attr('src', overImage);
#
#  		} catch (e) {
#  		}
#  	};
#
#  	resetMenuOver = function() {
#  		$('.menuitem').each(function(i) {
#  			try {
#  				var idValue = $(this).attr('id');
#  				if (idValue == null || idValue.length <= 4) {
#  					return;
#  				}
#
#  				var idxNo = parseInt(idValue.substring(4));
#  				var origImage = menuimages[(idxNo - 1) * 2];
#  				var overImage = menuimages[((idxNo - 1) * 2 + 1)];
#
#  				$(this).attr('src', origImage);
#  			} catch (e) {
#  			}
#  		});
#  	};
#
#  	hideSubMenus = function() {
#  		$('.smenuitem').each(function(i) {
#  			try {
#  				var idValue = $(this).attr('id');
#  				if (idValue == null || idValue.length <= 7) {
#  					return;
#  				}
#  				var idxNo = idValue.substring(7);
#
#  				$('#submenu'+idxNo).css('display', 'none');
#
#
#  			} catch (e) {
#  			}
#  		});
#  	};
#
#  	});
#
#
#  $(document).ready(function() {
#  	if($('#menu2').attr('src') == menuimages[2]) {
#    		if($('#menu3').attr('src') == menuimages[4]) {
#      		if($('#menu4').attr('src') == menuimages[6]) {
#        			if($('#menu5').attr('src') == menuimages[8]) {
#          			if($('#menu6').attr('src') == menuimages[10]) {
#            				if($('#menu7').attr('src') == menuimages[12]) {
#              				if($('#menu8').attr('src') == menuimages[14]) {
#                					$('#submenu1').css('display', 'inline');
#  	}}}}}}}
#  });
#
#  </script>
#  <!------구글 트랙킹 코드 google analytics start------->
#  <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#    (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#    m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#    })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#    ga('create', 'UA-24738742-1', 'auto');
#    ga('send', 'pageview');
#
#  </script>
#  <!------구글 트랙킹 코드 google analytics end------->
#  <!-- 테스트용 구글 트랙킹코드 -->
#  <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#    (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#    m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#    })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#    ga('create', 'UA-24738742-3', 'auto');
#    ga('send', 'pageview');
#
#  </script>
#  <!-- 테스트용 구글 트랙킹코드 -->
#  <!-- 리포트2.0 로그분석코드 시작 -->
#  <script type="text/javascript">
#  var JsHost = (("https:" == document.location.protocol) ? "https://" : "http://");
#  var uname = escape('에너지경제신문(PC)');
#  document.write(unescape("%3Cscript id='log_script' src='" + JsHost + "feelcoke.weblog.cafe24.com/weblog.js?uid=feelcoke&uname="+uname+"' type='text/javascript'%3E%3C/script%3E"));
#  </script>
#  <!-- 리포트2.0  로그분석코드 완료 -->
#  <!-- Dable 스크립트 시작 / 문의 support@dable.io -->
#  <script>
#  (function(d,a,b,l,e,_) {
#  d[b]=d[b]||function(){(d[b].q=d[b].q||[]).push(arguments)};e=a.createElement(l);
#  e.async=1;e.charset='utf-8';e.src='//static.dable.io/dist/plugin.min.js';
#  _=a.getElementsByTagName(l)[0];_.parentNode.insertBefore(e,_);
#  })(window,document,'dable','script');
#  dable('setService', 'ekn.kr');
#  dable('sendLog');
#  </script>
#  <!-- Dable 스크립트 종료 / 문의 support@dable.io -->
#  </div>
#  <!--//상단영역-->
#  <!--본문영역-->
#  <div id="container">
#  <!--컨테이너 레이아웃-->
#  <div class="layout_container">
#  <!--컨테이너영역-->
#  <div class="container">
#  <!-- 헤드라인 1단 2단 3단 합친영역-->
#  <div class="section_h123">
#  <!--/* OptimaA iFrame Tag v3.0.5 */-->
#  <div style="text-align:center; padding:20px; ">
#  <iframe frameborder="0" height="90" id="ab8c1519" name="ab8c1519" scrolling="no" src="http://www.ads-optima.com/www/delivery/afr.php?zoneid=572&amp;loc=http%3A%2F%2Fwww.ekn.kr%2Fnews%2Farticle.html%3Fno%3D433027" width="728">
#  <a href="http://www.ads-optima.com/www/delivery/ck.php?n=a5b50963&amp;cb=INSERT_RANDOM_NUMBER_HERE" target="_blank">
#  <img alt="" border="0" src="http://www.ads-optima.com/www/delivery/avw.php?zoneid=572&amp;cb=INSERT_RANDOM_NUMBER_HERE&amp;n=a5b50963"/>
#  </a>
#  </iframe>
#  </div>
#  <div class="m01_arv01">
#  <!-- s : 기사 제목 -->
#  <div class="viewsubject">
#  <div class="arvtitle">
#  <div class="hbox">
#  <h2>삼성생명, 삼성전자-제일기획 팔고 ‘삼성바이오’는 ‘사자’</h2>
#  <!--h3>특별계정 통해 삼성바이오-금융계열사 순매수...삼성전자 외인 매도에 주가 ‘주르륵’</h3-->
#  </div>
#  </div>
#  <p class="arvdate" style="">
#  <!-- <a href="/news/article_list_writer.html?name=%EB%82%98%EC%9C%A0%EB%9D%BC+%EA%B8%B0%EC%9E%90"> -->
#  <span>나유라 기자</span>
#  <!-- </a> -->
#  <a href="mailto:ys106@ekn.kr">ys106@ekn.kr</a>
#  			2019.05.21 07:14:10
#  		</p>
#  <div class="util_wrap">
#  <div class="util">
#  <ul>
#  <li class="line"><a href="javascript:openWin('/news/article_print.html?no=433027', 'print_pop', '790', '600', 'yes');"><img alt="프린트" onmouseout="kill();" onmouseover="popup('프린트하기','#E1FFFE');" src="/data/skin/content/1/m01_arv01/images/btn_print.gif"/></a></li>
#  <li class="line"><a href="javascript:openWin('/news/mail_form.html?no=433027', 'mail_pop', '700', '450', 'yes');"><img alt="메일" onmouseout="kill();" onmouseover="popup('메일전송','#E1FFFE');" src="/data/skin/content/1/m01_arv01/images/btn_mail.gif"/></a></li>
#  <li class="line"><a href="/news/scrap_proc.php?mode=insert&amp;no=433027"><img alt="스크랩" onmouseout="kill();" onmouseover="popup('스크랩하기','#E1FFFE');" src="/data/skin/content/1/m01_arv01/images/btn_scrap.gif"/></a></li>
#  <li><a href="/news/section.html?sec_no=103"><img alt="목록" onmouseout="kill();" onmouseover="popup('목록보기','#FFFFFF');" src="/data/skin/content/1/m01_arv01/images/btn_list.gif"/></a></li>
#  <li class="txt">글자크기</li>
#  <li><a href="#" onclick="javascript:news_large();"><img alt="크게" onmouseout="kill();" onmouseover="popup('크게','#E1FFFE');" src="/data/skin/content/1/m01_arv01/images/btn_bigger.gif"/></a></li>
#  <li><a href="#" onclick="javascript:news_small();"><img alt="작게" onmouseout="kill();" onmouseover="popup('작게','#E1FFFE');" src="/data/skin/content/1/m01_arv01/images/btn_smaller.gif"/></a> </li>
#  <!-- <li><a href="#openSns" onclick="javascript:CenterWin('https://twitter.com/intent/tweet?text=%EC%82%BC%EC%84%B1%EC%83%9D%EB%AA%85%2C+%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90-%EC%A0%9C%EC%9D%BC%EA%B8%B0%ED%9A%8D+%ED%8C%94%EA%B3%A0+%E2%80%98%EC%82%BC%EC%84%B1%EB%B0%94%EC%9D%B4%EC%98%A4%E2%80%99%EB%8A%94+%E2%80%98%EC%82%AC%EC%9E%90%E2%80%99&url=http%3A%2F%2Fwww.ekn.kr%2Fnews%2Farticle.html%3Fno%3D433027','snsSend_tw','toolbar=no,location=no,directories=no,status=no,menubar=no,scrollbars=yes,resizable=yes,width=600,height=430'); return false;"><img src="/images/sns/btn_tw1.gif" style="border: 0;" ONMOUSEOVER="popup('트위터 보내기','#FFFFCC');" ONMOUSEOUT="kill();" /></a></li> -->
#  <li><a href="#openSns" onclick="javascript:CenterWin('https://twitter.com/intent/tweet?text=%EC%82%BC%EC%84%B1%EC%83%9D%EB%AA%85%2C+%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90-%EC%A0%9C%EC%9D%BC%EA%B8%B0%ED%9A%8D+%ED%8C%94%EA%B3%A0+%E2%80%98%EC%82%BC%EC%84%B1%EB%B0%94%EC%9D%B4%EC%98%A4%E2%80%99%EB%8A%94+%E2%80%98%EC%82%AC%EC%9E%90%E2%80%99&amp;url=http%3A%2F%2Fwww.ekn.kr%2Fnews%2Farticle.html%3Fno%3D433027','snsSend_tw','toolbar=no,location=no,directories=no,status=no,menubar=no,scrollbars=yes,resizable=yes,width=600,height=430'); return false;"><img onmouseout="kill();" onmouseover="popup('트위터 보내기','#FFFFCC');" src="/data/skin/content/1/m01_arv01/images/snsc_twt.png" style="border: 0;width: 40px;"/></a></li>
#  <!-- <li><a href="javascript:facebook_share('http%3A%2F%2Fwww.ekn.kr%2Fnews%2Farticle.html%3Fno%3D433027')"><img src="/images/sns/btn_fb1.gif" style="border: 0;" ONMOUSEOVER="popup('페이스북 보내기','#FFFFCC');" ONMOUSEOUT="kill();" /></a></li> -->
#  <li><a href="javascript:facebook_share('http%3A%2F%2Fwww.ekn.kr%2Fnews%2Farticle.html%3Fno%3D433027')"><img onmouseout="kill();" onmouseover="popup('페이스북 보내기','#FFFFCC');" src="/data/skin/content/1/m01_arv01/images/snsc_fbk.png" style="border:0;width:40px;"/></a></li>
#  <li><a href="javascript:shareStory();"><img onmouseout="kill();" onmouseover="popup('카카오스토리 공유','#FFFFCC');" src="/data/skin/content/1/m01_arv01/images/snsc_kakaoSt.png" style="border:0;width:40px;"/></a></li>
#  <li><a href="javascript:copyToClipboard();"><img onmouseout="kill();" onmouseover="popup('URL복사','#FFFFCC');" src="/data/skin/content/1/m01_arv01/images/url_share_40x40.png" style="border:0;width:40px;"/></a></li>
#  </ul>
#  </div>
#  </div>
#  <div style="clear:both;"></div>
#  </div>
#  <!-- s : 기사 제목 -->
#  </div>
#  <!-- 우측 날개 광고스크립트-->
#  <style type="text/css">
#  								.fixed_r {position:absolute;width:160px; height:600px;position:absolute;right:50%;margin-right:-660px;top:350px;z-index:1; padding-top:155px;}
#  								.fixed_r2 {position:absolute;width:160px; height:600px;position:absolute;right:50%;margin-right:-660px;top:1000px;z-index:1; padding-top:115px;}
#  							</style>
#  <div class="fixed_r">
#  <!--/* OptimaA iFrame Tag v3.0.5 */-->
#  <iframe frameborder="0" height="600" id="a9013f50" name="a9013f50" scrolling="no" src="http://www.ads-optima.com/www/delivery/afr.php?zoneid=574&amp;loc=http%3A%2F%2Fwww.ekn.kr%2Fnews%2Farticle.html%3Fno%3D433027" width="120">
#  <a href="http://www.ads-optima.com/www/delivery/ck.php?n=a8a2b116&amp;cb=INSERT_RANDOM_NUMBER_HERE" target="_blank">
#  <img alt="" border="0" src="http://www.ads-optima.com/www/delivery/avw.php?zoneid=574&amp;cb=INSERT_RANDOM_NUMBER_HERE&amp;n=a8a2b116"/>
#  </a>
#  </iframe>
#  </div>
#  <div class="fixed_r2">
#  <!--/* OptimaA iFrame Tag v3.0.5 */-->
#  <iframe frameborder="0" height="600" id="a9169fe6" name="a9169fe6" scrolling="no" src="http://www.ads-optima.com/www/delivery/afr.php?zoneid=575&amp;loc=http%3A%2F%2Fwww.ekn.kr%2Fnews%2Farticle.html%3Fno%3D433027" width="120">
#  <a href="http://www.ads-optima.com/www/delivery/ck.php?n=afa695f4&amp;cb=INSERT_RANDOM_NUMBER_HERE" target="_blank">
#  <img alt="" border="0" src="http://www.ads-optima.com/www/delivery/avw.php?zoneid=575&amp;cb=INSERT_RANDOM_NUMBER_HERE&amp;n=afa695f4"/>
#  </a>
#  </iframe>
#  </div>
#  <!--우측 날개 광고스크립트-->
#  <!--  왼쪽 날개 광고스크립트-->
#  <style type="text/css">
#  								.fixed1 {position:absolute;width:160px; height:600px;position:absolute;left:50%;margin-left:-620px;top:350px;z-index:1; padding-top:155px;}
#  							</style>
#  <div class="fixed1">
#  <div style="position:relative;">
#  <iframe allowtransparency="true" frameborder="0" height="619" scrolling="no" src="http://adsvc2.wisenut.co.kr/amc/29/amc_svc_iframe_1.php?c=1730&amp;t=1&amp;s=3322&amp;l=Y&amp;e=136&amp;f=Y&amp;cs=euc-kr&amp;cr=Y" width="120"></iframe>
#  </div>
#  </div>
#  <!-- 헤드라인 1단 2단 합친영역-->
#  <div class="section_h12">
#  <!--1단 2단 합친영역-->
#  <div class="section_12">
#  <!-- netinsight recommend script start -->
#  <script src="http://rec.netinsight.co.kr/facebook.netinsight.recommend.controller.js" type="text/javascript"></script>
#  <script type="text/javascript">
#  var NISPublisher='ekn';
#  var recommend=new NISRecommend(NISPublisher);
#  recommend.setArticle('241', '241', '433027', '2019.05.21 07:14:10');
#  recommend.send();
#  </script>
#  <!-- netinsight recommend end start -->
#  <div class="m01_arv02">
#  <!-- 다음 송고 -->
#  <!-- 	<div style="text-align: center;">
#  		<img src="http://cp.news.search.daum.net/api/publish.json?nurl=http%3A%2F%2Fwww.ekn.kr%2Fnews%2Farticle.html%3Fno%3D433027&xml_url=http%3A%2F%2Fwww.ekn.kr%2Fnews%2Farticle.html%3Fno%3D433027%26type%3Dxml&channel=business" style="display:none;"/>
#  	</div>
#   -->
#  <!-- 다음 송고 -->
#  <script>
#  function facebook_share($url){
#    $facebook_url="https://www.facebook.com/sharer/sharer.php?app_id=114545895322903&sdk=joey&u="+$url+"&display=popup&ref=plugin&src=share_button";
#    fawin = window.open($facebook_url, 'fawin', 'width=600,height=500,scrollbars=no,resizable=no');
#    if (fawin) fawin.focus();
#  }
#  </script>
#  <div class="cnt_view news_body_area">
#  <h3 class="stit">특별계정 통해 삼성바이오-금융계열사 순매수...삼성전자 외인 매도에 주가 ‘주르륵’</h3>
#  <!-- 기사본공 필수 공용 : Smart Editor Style Sheet -->
#  <link href="/plugin/SEditor/css/style.css?20160318" rel="stylesheet" type="text/css"/>
#  <link href="/js/ckeditor/contents.css" rel="stylesheet" type="text/css"/>
#  <!-- s : 기사 본문 -->
#  <!---//온라인2팀 광고주 요청으로 div태그 삽입---->
#  <div id="CmAdContent">
#  <div class="smartOutput" id="news_body_area">
#  <div id="news_body_area_contents" itemprop="articleBody">
#  <div class="imgframe sm-image-c" style="width:540px;"><img class="" src="http://cdn.ekn.kr/data/photos/cdn/20190520/2019052001000842600033761.jpg" title="(사진=연합) " xtype="photo"/><div class="imgcaption2"><p style="margin:0; padding:5px; font-size:12px; text-align:left;  background:#333; color:#fff; line-height:1.4em;">▲(사진=연합)</p></div></div><br/>[에너지경제신문=나유라 기자] 삼성생명이 특별계정을 통해 삼성전자와 제일기획을 대거 매도하고 삼성바이오로직스는 1200주 넘게 사들인 것으로 나타났다. <br/><br/>20일 금융감독원 전자공시시스템에 따르면 삼성생명은 특별계정을 통해 삼성전자 주식을 보통주 기준 지난달 24일 1835만1459주에서 이달 15일 1829만3102주로 5만8000주 넘게 팔아치웠다. 삼성생명 특별계정은 변액보험 자금을 관리하는 계정으로, 삼성생명의 자금을 위탁받은 운용사들이 투자를 위해 매매하는 계정을 말한다. 의결권이 없고, 어떤 운용사가 운용하는지는 알려지지 않았다.<br/><br/>외국인도 지난달 24일부터 삼성전자 주식을 3536억원어치 팔아치웠다. 최근 원/달러 환율 강세, 미중 무역분쟁 등으로 국내 대장주를 집중적으로 팔아치우면서 삼성전자에도 매도세가 몰린 것으로 분석된다. 이 영향으로 삼성전자 주가는 지난달 24일부터 이달까지 6% 넘게 빠졌다. 삼성전자는 올해 2분기를 저점으로 하반기부터 실적이 개선될 것으로 기대된다. 2분기 영업이익 6조235억원으로 전년 동기 대비 60%가량 급감할 것으로 추정되나, 2분기 말부터 D램과 낸드플래시의 수요가 회복되면서 실적도 차츰 개선될 것으로 보고 있다. <br/><br/><table align="center" border="0" bordercolor="#000000" cellpadding="0" cellspacing="0" style="border-collapse:collapse">
#  <tbody><tr>
#  <td colspan="5" style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 713pt; height: 16pt;text-align :center;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 11.9pt;letter-spacing: -0.4pt;line-height: 18.2pt;color: #000000"></span><span style="font-size: 11.9pt;letter-spacing: -0.4pt;line-height: 18.2pt;color: #000000">&lt;삼성생명 특별계정 소유주식 변동 현황&gt;</span></td>
#  </tr>
#  <tr>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-left-style:none;border-right-style:none; width: 94pt; height: 14pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 10.2pt;letter-spacing: -0.4pt;line-height: 15.6pt;color: #000000"></span><span style="font-size: 10.2pt;letter-spacing: -0.4pt;line-height: 15.6pt;color: #1F487D">종목명</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-left-style:none;border-right-style:none; width: 220pt; height: 14pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 10.2pt;letter-spacing: -0.4pt;line-height: 15.6pt;color: #000000"></span><span style="font-size: 10.2pt;letter-spacing: -0.4pt;line-height: 15.6pt;color: #1F487D">변경 전 주식 수(시기)</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-left-style:none;border-right-style:none; width: 166pt; height: 14pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 10.2pt;letter-spacing: -0.4pt;line-height: 15.6pt;color: #000000"></span><span style="font-size: 10.2pt;letter-spacing: -0.4pt;line-height: 15.6pt;color: #1F487D">변경 후 주식 수(시기)</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-left-style:none;border-right-style:none; width: 92pt; height: 14pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 10.2pt;letter-spacing: -0.4pt;line-height: 15.6pt;color: #000000"></span><span style="font-size: 10.2pt;letter-spacing: -0.4pt;line-height: 15.6pt;color: #1F487D">수량</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-left-style:none;border-right-style:none; width: 141pt; height: 14pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 10.2pt;letter-spacing: -0.4pt;line-height: 15.6pt;color: #000000"></span><span style="font-size: 10.2pt;letter-spacing: -0.4pt;line-height: 15.6pt;color: #1F487D">연초 이후 주가 추이</span></td>
#  </tr>
#  <tr>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 94pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">삼성전자</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 220pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">1835만1459주(4/24)</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 166pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">1829만3102주(5/15)</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 92pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">5만8357주 순매도</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 141pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">-6.15%</span></td>
#  </tr>
#  <tr>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 94pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">제일기획</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 220pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">19만2509주(4/2)</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 166pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">17만2950주(5/17)</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 92pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">1만9559주 순매도</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 141pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">15.47%</span></td>
#  </tr>
#  <tr>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 94pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">삼성바이오로직스</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 220pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">5만4414주(3/25)</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 166pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">5만5669주(4/25)</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 92pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">1255주 순매수</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 141pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">-21.52%</span></td>
#  </tr>
#  <tr>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 94pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">삼성증권</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 220pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">2636만6300주(4/5)</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 166pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">2636만6452주(5/17)</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 92pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">152주 순매수</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 141pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">10.24%</span></td>
#  </tr>
#  <tr>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 94pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">삼성화재</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 220pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">711만6349주(4/5)</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 166pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">711만7118주(5/17)</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 92pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">769주 순매수</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 141pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">4.73%</span></td>
#  </tr>
#  <tr>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 94pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">삼성카드</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 220pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">8327만5984주(4/5)</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 166pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">8327만6206주(5/17)</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 92pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">222주 순매수</span></td>
#  <td style="border-style:solid; border-width:1px;border-top-style:none;border-bottom-style:none;border-left-style:none;border-right-style:none; width: 141pt; height: 13pt;text-align :left;vertical-align :middle;background-color: #FFFFFF;"><span style="font-size: 6.6pt;letter-spacing: -0.4pt;line-height: 10.1pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000"></span><span style="font-size: 9.3pt;letter-spacing: -0.4pt;line-height: 14.3pt;color: #000000">3.75%</span></td>
#  </tr>
#  </tbody></table><br/><br/>삼성생명은 지난달 2일부터 이달 17일까지 제일기획 주식도 1만9559주 팔아치웠다. 올해 들어 주가가 15% 넘게 오르면서 일부 차익실현에 나선 것으로 풀이된다. 증권가에서는 제일기획이 올해 해외 자회사, 디지털 광고 성장에 힘입어 연간 영업이익이 10% 불어난 2004억원을 올릴 것으로 보고 있다. 제일기획은 지난해 평창올림픽 기저 효과와 국내 대형 광고주 이탈에도 1분기 영업이익 322억원으로 호실적을 달성했다는 평가를 받고 있다.<br/><br/>반면 삼성생명은 3월 25일부터 지난달 29일까지 삼성바이오로직스 주식 1255주를 순매수했다. 다만 매수 물량이 많지 않은데다 검찰이 분식회계와 관련해 윗선 수사에 속도를 내면서 주가는 지지부진하다. 삼성바이오로직스는 올해 들어 기관과 외국인이 각각 1446억원, 758억원어치 팔아치우면서 주가가 20% 넘게 급락했다. <br/><br/>이밖에 삼성생명은 지난달 5일부터 이달 17일까지 삼성증권(152주), 삼성화재(769주), 삼성카드(222주) 등 금융계열사 주식을 순매수했다. 이 중 삼성증권 주가는 올해 1월 2일 3만1250원에서 지난달 17일 3만7800원까지 오르며 연중 최고점을 찍었다. 이달 들어 3만4450원으로 소폭 하락하긴 했지만 1분기 연결순이익 1172억원으로 전분기 대비 214.7% 급증하며 삼성증권의 저력을 확인했다는 평가다. 증권업계 관계자는 "특별계정은 보험사 직접 계정과 달리 의결권이 없고, 위탁운용사가 투자 목적으로 사고 판 내역을 의미한다"며 "특별계정에 들어있는 대표적인 상품이 변액보험으로, 삼성생명이 위탁운용사 매매에 대해 왈가왈부할 수 없다"고 설명했다.<br/><br/><br/>
#  </div>
#  </div>
#  </div>
#  <!---온라인2팀 광고주 요청으로 div태그 삽입//---->
#  <!-- e : 기사 본문 -->
#  <!-- 20160310 나우센스 기사 제휴 -->
#  <div id="now-sence">
#  <script src="http://script.nowcall.co.kr/nowsence/nsLiveNewsBanner.js" type="text/javascript"></script>
#  </div>
#  <!-- 20160310 나우센스 기사 제휴 -->
#  <!-- 카피라이트 -->
#  <p class="copyright">&lt; 저작권자 ⓒ 에너지경제 무단전재 및 재배포 금지 / 대한민국 경제의 힘, 에너지경제&gt;</p>
#  <!-- //카피라이트 -->
#  <!-- <div class="articlein_ad" style="visibility: hidden;">
#  	<div class="articlein_ad_content" style="margin-bottom:10px;">
#  		<div id="elpVideoBody">&nbsp;</div>
#  	</div>
#  </div> -->
#  <!-- <script type="text/javascript">
#  $(function(){
#      $('#news_body_area_contents').contents().filter(function() {
#             return this.nodeType == 1;
#       }).wrap('<span></span>');
#
#      var spanLength = $("#news_body_area_contents > span").length;
#      var spanPos = Math.round(spanLength * 0.5);
#      $("#news_body_area_contents > span").eq(spanPos).after($(".articlein_ad_content"));
#      $(".articlein_ad").remove();
#  });
#
# ...
#  </dt>
#  <dd class="sum"><a href="/news/article.html?no=432530">[단독] LG화학 유럽 제2공장, 폴란드 우츠·오플레 '2파전'</a></dd>
#  </dl>
#  <dl class="photo_news">
#  <dt class="img">
#  <a href="/news/article.html?no=432513"><img alt="[단독] 한전 소액주주 뿔났다....20일 한전강남지사 앞에서 적자비판 시위 개최" height="50" src="http://cdn.ekn.kr/data/cache/public/photos/cdn/20190520/art_1558046863_70x50.jpg" width="70"/></a>
#  </dt>
#  <dd class="sum"><a href="/news/article.html?no=432513">[단독] 한전 소액주주 뿔났다....20일 한전강남지사 앞에서 적자비판 시위…</a></dd>
#  </dl>
#  <dl class="photo_news">
#  <dt class="img">
#  <a href="/news/article.html?no=432293"><img alt="[단독] 한국타이어, 미국 노동법 위반…65만 달러 지급 명령" height="50" src="http://cdn.ekn.kr/data/cache/public/photos/cdn/20190520/art_1557962919_70x50.jpg" width="70"/></a>
#  </dt>
#  <dd class="sum"><a href="/news/article.html?no=432293">[단독] 한국타이어, 미국 노동법 위반…65만 달러 지급 명령</a></dd>
#  </dl>
#  </div>
#  </div>, <div class="photo_list">
#  <dl class="photo_news">
#  <dt class="img">
#  <a href="/news/article.html?no=433154"><img alt="[단독] KCGI '한진칼 지분' 추가 매입한다...조원태 회장과 본격 맞대결" height="50" src="http://cdn.ekn.kr/data/cache/public/photos/cdn/20190521/art_1558404957_70x50.jpg" width="70"/></a>
#  </dt>
#  <dd class="sum"><a href="/news/article.html?no=433154">[단독] KCGI '한진칼 지분' 추가 매입한다...조원태 회장과 본격 맞대결</a></dd>
#  </dl>
#  <dl class="photo_news">
#  <dt class="img">
#  <a href="/news/article.html?no=432530"><img alt="[단독] LG화학 유럽 제2공장, 폴란드 우츠·오플레 '2파전'" height="50" src="http://cdn.ekn.kr/data/cache/public/photos/cdn/20190520/art_1558073688_70x50.jpg" width="70"/></a>
#  </dt>
#  <dd class="sum"><a href="/news/article.html?no=432530">[단독] LG화학 유럽 제2공장, 폴란드 우츠·오플레 '2파전'</a></dd>
#  </dl>
#  <dl class="photo_news">
#  <dt class="img">
#  <a href="/news/article.html?no=432513"><img alt="[단독] 한전 소액주주 뿔났다....20일 한전강남지사 앞에서 적자비판 시위 개최" height="50" src="http://cdn.ekn.kr/data/cache/public/photos/cdn/20190520/art_1558046863_70x50.jpg" width="70"/></a>
#  </dt>
#  <dd class="sum"><a href="/news/article.html?no=432513">[단독] 한전 소액주주 뿔났다....20일 한전강남지사 앞에서 적자비판 시위…</a></dd>
#  </dl>
#  <dl class="photo_news">
#  <dt class="img">
#  <a href="/news/article.html?no=432293"><img alt="[단독] 한국타이어, 미국 노동법 위반…65만 달러 지급 명령" height="50" src="http://cdn.ekn.kr/data/cache/public/photos/cdn/20190520/art_1557962919_70x50.jpg" width="70"/></a>
#  </dt>
#  <dd class="sum"><a href="/news/article.html?no=432293">[단독] 한국타이어, 미국 노동법 위반…65만 달러 지급 명령</a></dd>
#  </dl>
#  </div>, <div style="width:100%; height:15px;"></div>, <div style=" width:100%px; border-top:1px solid #e4e4e4; padding-bottom:10px; "></div>, <div style="width:100%; height:10px;"></div>, <div data-widget_id="ml6KqAX4" id="dablewidget_ml6KqAX4">
#  <script>
#    (function(d,a){d[a]=d[a]||function(){(d[a].q=d[a].q||[]).push(arguments)};}(window,'dable'));
#    dable('renderWidget', 'dablewidget_ml6KqAX4');
#    </script>
#  </div>, <div style="width:100%; height:15px;"></div>, <div style=" width:100%px; border-top:1px solid #e4e4e4; padding-bottom:10px; "></div>, <div style="width:100%; height:10px;"></div>, <div style="width:100%; height:15px;"></div>, <div style=" width:100%px; border-top:1px solid #e4e4e4; padding-bottom:10px; "></div>, <div style="width:100%; height:15px;"></div>, <div class="m01_arl93">
#  <a href="/news/review_list_all.html?rvw_no=245">
#  <h2>
#      		[에경TV] 디지털 콘텐츠
#      	</h2>
#  </a>
#  <ul class="bxslider">
#  <li>
#  <a href="/news/article.html?no=96946">
#  <span class="img">
#  <img alt="'경영의 신' 마쓰시타 고노스케 회장의 성공철학" src="http://cdn.ekn.kr/data/cache/public/photos/cdn/20180101/art_1515033453_255x190.jpg" title="'경영의 신' 마쓰시타 고노스케 회장의 성공철학"/>
#  </span>
#  <span class="txt">'경영의 신' 마쓰시타 고노스케 회장의 성공철학</span>
#  </a>
#  </li>
#  </ul>
#  </div>, <div style="width:100%; height:15px;"></div>, <div id="footer">
#  <div class="layout_footer">
#  <div class="menu_area">
#  <div class="menu">
#  <ul>
#  <li><a href="/home/company.html?page_no=1">회사소개</a>|</li>
#  <li><a href="/home/company.html?page_no=1&amp;mode=recruit">인재채용</a>|</li>
#  <!-- <li><a href="javascript:void(0);" onclick="changeBody('08', 'false');">인재채용</a></li> -->
#  <li><a href="javascript:doPopup('http://www.ekn.kr/news/request_form.html?mode=order', 600, 600, 'yes')">구독신청</a>|</li>
#  <li><a href="javascript:doPopup('/news/request_form.html?mode=report', 600, 600, 'yes')">기사제보</a>|</li>
#  <li><a href="javascript:doPopup('/member/agree_info.html?mode=private&amp;type=main', 600, 600, 'yes')"><strong>개인정보취급방침</strong></a>|</li>
#  <li><a href="javascript:doPopup('/member/agree_info.html?mode=email&amp;type=main', 600, 600, 'yes')">이메일 무단수집거부</a>|</li>
#  <li><a href="javascript:doPopup('/member/agree_info.html?mode=teenager&amp;type=main', 600, 600, 'yes')">청소년보호방침</a>|</li>
#  <li><a href="javascript:doPopup('/news/problem.html', 600, 600, 'yes')">고충처리</a>|</li>
#  <li class="bgnone"><a href="javascript:doPopup('/news/request_form.html?mode=contact', 600, 600, 'yes')">문의하기</a></li>
#  </ul>
#  </div>
#  </div>
#  <div class="copyright_area">
#  <div class="copyright">
#  <div class="logo">
#  <a href="/" onfocus="blur()" target="_top"><img alt="로고" height="38" src="/data/design/logo/taillogo_20161215213757.jpg" width="149"/></a>
#  </div>
#  <div class="add">
#              ㈜에너지경제신문사(제호:에너지경제) ｜ 등록번호:서울아02241 ｜ 등록일자:2012.08.30<br/>
#  발행인 : 송용희 ｜ 편집인 : 임정효 ｜ 서울특별시 중구 새문안로 26, 청양빌딩 5층<br/>
#  발행일자 : 1989.05.26 ｜ 대표전화 : 02)850-0114 ｜ 팩스 : 02)867-0453 <br/>
#  청소년보호책임자:박성준<br/>
#  <br/>
#  Mail to : ekn@ekn.kr<br/>
#  Copyright © 2013 에너지경제신문. All rights reserved.
#              </div>
#  <div class="internet">
#  <a href="https://www.inc.or.kr/" target="_blank"><img alt="인터넷신문위원회" src="/data/skin/layout/1/m01/images/footer/20170214_InternetBanner_Tail.jpg"/></a>
#  </div>
#  <div class="powered">
#  <a href="http://www.kpf.or.kr/" target="_blank"><img alt="powered by 한국언론진흥재단" src="/data/skin/layout/1/m01/images/footer/powered.png"/></a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <a href="/?mobile=N"><div class="mobile_go">모바일 보기</div></a>
#  <script type="text/javascript">document.write(unescape("%3Cscript src='/weblog/gtracker.js' type='text/javascript'%3E%3C/script%3E"));</script>
#  <!-- Piwik -->
#  <script type="text/javascript">
#    var _paq = _paq || [];
#    _paq.push(["setDocumentTitle", document.domain + "/" + document.title]);
#    _paq.push(["setCookieDomain", "*.ekn.kr"]);
#    _paq.push(["setDomains", ["*.ekn.kr","*.ekn.kr"]]);
#    _paq.push(["trackPageView"]);
#    _paq.push(["enableLinkTracking"]);
#
#    (function() {
#      var u=(("https:" == document.location.protocol) ? "https" : "http") + "://weblog.newscloud.or.kr/";
#      _paq.push(["setTrackerUrl", u+"piwik.php"]);
#      _paq.push(["setSiteId", "17"]);
#      var d=document, g=d.createElement("script"), s=d.getElementsByTagName("script")[0]; g.type="text/javascript";
#      g.defer=true; g.async=true; g.src=u+"piwik.js"; s.parentNode.insertBefore(g,s);
#    })();
#  </script>
#  <!-- End Piwik Code -->
#  <!-- 네이버 애날리스틱-->
#  <script src="http://wcs.naver.net/wcslog.js" type="text/javascript"></script>
#  <script type="text/javascript">
#  if(!wcs_add) var wcs_add = {};
#  wcs_add["wa"] = "95b93ec02df7dc";
#  wcs_do();
#  </script>
#  <!-- 네이버 애날리스틱-->
#  <!-- 20170511 cs8321, Google 리마케팅 태그 코드 -->
#  <script type="text/javascript">
#  /* <![CDATA[ */
#  var google_conversion_id = 856690710;
#  var google_custom_params = window.google_tag_params;
#  var google_remarketing_only = true;
#  /* ]]> */
#  </script>
#  <script src="//www.googleadservices.com/pagead/conversion.js" type="text/javascript">
#  </script>
#  <noscript>
#  <div style="display:inline;">
#  <img alt="" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/856690710/?guid=ON&amp;script=0" style="border-style:none;" width="1"/>
#  </div>
#  </noscript>
#  <!-- //20170511 cs8321, Google 리마케팅 태그 코드 -->
#  <script type="text/javascript">
#  	$.post("//weblog.amicms.co.kr/weblog", "referer="+encodeURIComponent(document.referrer)+"&site_code=ekn");
#
#  	$(function(){
#  		$("a").click(function(){
#  			var type = $(this).data("cnt_type");
#  			if(typeof(type) != "undefined")
#  			{
#  				$.post("//weblog.amicms.co.kr/weblog/tracking", "site_code=ekn&type="+type+"&target_url="+encodeURIComponent($(this).attr("href")));
#  			}
#  		});
#
#  		if($.browser.mobile == true)
#  		{
#  			$(".mobile_go").show();
#  		}
#  	});
#  </script>
#  <!-- 20181026 원종필 모니터링을 위해서 추가함 요거는 전체 페이지에 대해서 수행되어야 해서 iframe 등에도 별도로 넣음Global site tag (gtag.js) - Google Analytics -->
#  <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-128187796-1"></script>
#  <script>
#    window.dataLayer = window.dataLayer || [];
#    function gtag(){dataLayer.push(arguments);}
#    gtag('js', new Date());
#
#    gtag('config', 'UA-128187796-1');
#  </script>
#  </div>, <div class="layout_footer">
#  <div class="menu_area">
#  <div class="menu">
#  <ul>
#  <li><a href="/home/company.html?page_no=1">회사소개</a>|</li>
#  <li><a href="/home/company.html?page_no=1&amp;mode=recruit">인재채용</a>|</li>
#  <!-- <li><a href="javascript:void(0);" onclick="changeBody('08', 'false');">인재채용</a></li> -->
#  <li><a href="javascript:doPopup('http://www.ekn.kr/news/request_form.html?mode=order', 600, 600, 'yes')">구독신청</a>|</li>
#  <li><a href="javascript:doPopup('/news/request_form.html?mode=report', 600, 600, 'yes')">기사제보</a>|</li>
#  <li><a href="javascript:doPopup('/member/agree_info.html?mode=private&amp;type=main', 600, 600, 'yes')"><strong>개인정보취급방침</strong></a>|</li>
#  <li><a href="javascript:doPopup('/member/agree_info.html?mode=email&amp;type=main', 600, 600, 'yes')">이메일 무단수집거부</a>|</li>
#  <li><a href="javascript:doPopup('/member/agree_info.html?mode=teenager&amp;type=main', 600, 600, 'yes')">청소년보호방침</a>|</li>
#  <li><a href="javascript:doPopup('/news/problem.html', 600, 600, 'yes')">고충처리</a>|</li>
#  <li class="bgnone"><a href="javascript:doPopup('/news/request_form.html?mode=contact', 600, 600, 'yes')">문의하기</a></li>
#  </ul>
#  </div>
#  </div>
#  <div class="copyright_area">
#  <div class="copyright">
#  <div class="logo">
#  <a href="/" onfocus="blur()" target="_top"><img alt="로고" height="38" src="/data/design/logo/taillogo_20161215213757.jpg" width="149"/></a>
#  </div>
#  <div class="add">
#              ㈜에너지경제신문사(제호:에너지경제) ｜ 등록번호:서울아02241 ｜ 등록일자:2012.08.30<br/>
#  발행인 : 송용희 ｜ 편집인 : 임정효 ｜ 서울특별시 중구 새문안로 26, 청양빌딩 5층<br/>
#  발행일자 : 1989.05.26 ｜ 대표전화 : 02)850-0114 ｜ 팩스 : 02)867-0453 <br/>
#  청소년보호책임자:박성준<br/>
#  <br/>
#  Mail to : ekn@ekn.kr<br/>
#  Copyright © 2013 에너지경제신문. All rights reserved.
#              </div>
#  <div class="internet">
#  <a href="https://www.inc.or.kr/" target="_blank"><img alt="인터넷신문위원회" src="/data/skin/layout/1/m01/images/footer/20170214_InternetBanner_Tail.jpg"/></a>
#  </div>
#  <div class="powered">
#  <a href="http://www.kpf.or.kr/" target="_blank"><img alt="powered by 한국언론진흥재단" src="/data/skin/layout/1/m01/images/footer/powered.png"/></a>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="menu_area">
#  <div class="menu">
#  <ul>
#  <li><a href="/home/company.html?page_no=1">회사소개</a>|</li>
#  <li><a href="/home/company.html?page_no=1&amp;mode=recruit">인재채용</a>|</li>
#  <!-- <li><a href="javascript:void(0);" onclick="changeBody('08', 'false');">인재채용</a></li> -->
#  <li><a href="javascript:doPopup('http://www.ekn.kr/news/request_form.html?mode=order', 600, 600, 'yes')">구독신청</a>|</li>
#  <li><a href="javascript:doPopup('/news/request_form.html?mode=report', 600, 600, 'yes')">기사제보</a>|</li>
#  <li><a href="javascript:doPopup('/member/agree_info.html?mode=private&amp;type=main', 600, 600, 'yes')"><strong>개인정보취급방침</strong></a>|</li>
#  <li><a href="javascript:doPopup('/member/agree_info.html?mode=email&amp;type=main', 600, 600, 'yes')">이메일 무단수집거부</a>|</li>
#  <li><a href="javascript:doPopup('/member/agree_info.html?mode=teenager&amp;type=main', 600, 600, 'yes')">청소년보호방침</a>|</li>
#  <li><a href="javascript:doPopup('/news/problem.html', 600, 600, 'yes')">고충처리</a>|</li>
#  <li class="bgnone"><a href="javascript:doPopup('/news/request_form.html?mode=contact', 600, 600, 'yes')">문의하기</a></li>
#  </ul>
#  </div>
#  </div>, <div class="menu">
#  <ul>
#  <li><a href="/home/company.html?page_no=1">회사소개</a>|</li>
#  <li><a href="/home/company.html?page_no=1&amp;mode=recruit">인재채용</a>|</li>
#  <!-- <li><a href="javascript:void(0);" onclick="changeBody('08', 'false');">인재채용</a></li> -->
#  <li><a href="javascript:doPopup('http://www.ekn.kr/news/request_form.html?mode=order', 600, 600, 'yes')">구독신청</a>|</li>
#  <li><a href="javascript:doPopup('/news/request_form.html?mode=report', 600, 600, 'yes')">기사제보</a>|</li>
#  <li><a href="javascript:doPopup('/member/agree_info.html?mode=private&amp;type=main', 600, 600, 'yes')"><strong>개인정보취급방침</strong></a>|</li>
#  <li><a href="javascript:doPopup('/member/agree_info.html?mode=email&amp;type=main', 600, 600, 'yes')">이메일 무단수집거부</a>|</li>
#  <li><a href="javascript:doPopup('/member/agree_info.html?mode=teenager&amp;type=main', 600, 600, 'yes')">청소년보호방침</a>|</li>
#  <li><a href="javascript:doPopup('/news/problem.html', 600, 600, 'yes')">고충처리</a>|</li>
#  <li class="bgnone"><a href="javascript:doPopup('/news/request_form.html?mode=contact', 600, 600, 'yes')">문의하기</a></li>
#  </ul>
#  </div>, <div class="copyright_area">
#  <div class="copyright">
#  <div class="logo">
#  <a href="/" onfocus="blur()" target="_top"><img alt="로고" height="38" src="/data/design/logo/taillogo_20161215213757.jpg" width="149"/></a>
#  </div>
#  <div class="add">
#              ㈜에너지경제신문사(제호:에너지경제) ｜ 등록번호:서울아02241 ｜ 등록일자:2012.08.30<br/>
#  발행인 : 송용희 ｜ 편집인 : 임정효 ｜ 서울특별시 중구 새문안로 26, 청양빌딩 5층<br/>
#  발행일자 : 1989.05.26 ｜ 대표전화 : 02)850-0114 ｜ 팩스 : 02)867-0453 <br/>
#  청소년보호책임자:박성준<br/>
#  <br/>
#  Mail to : ekn@ekn.kr<br/>
#  Copyright © 2013 에너지경제신문. All rights reserved.
#              </div>
#  <div class="internet">
#  <a href="https://www.inc.or.kr/" target="_blank"><img alt="인터넷신문위원회" src="/data/skin/layout/1/m01/images/footer/20170214_InternetBanner_Tail.jpg"/></a>
#  </div>
#  <div class="powered">
#  <a href="http://www.kpf.or.kr/" target="_blank"><img alt="powered by 한국언론진흥재단" src="/data/skin/layout/1/m01/images/footer/powered.png"/></a>
#  </div>
#  </div>
#  </div>, <div class="copyright">
#  <div class="logo">
#  <a href="/" onfocus="blur()" target="_top"><img alt="로고" height="38" src="/data/design/logo/taillogo_20161215213757.jpg" width="149"/></a>
#  </div>
#  <div class="add">
#              ㈜에너지경제신문사(제호:에너지경제) ｜ 등록번호:서울아02241 ｜ 등록일자:2012.08.30<br/>
#  발행인 : 송용희 ｜ 편집인 : 임정효 ｜ 서울특별시 중구 새문안로 26, 청양빌딩 5층<br/>
#  발행일자 : 1989.05.26 ｜ 대표전화 : 02)850-0114 ｜ 팩스 : 02)867-0453 <br/>
#  청소년보호책임자:박성준<br/>
#  <br/>
#  Mail to : ekn@ekn.kr<br/>
#  Copyright © 2013 에너지경제신문. All rights reserved.
#              </div>
#  <div class="internet">
#  <a href="https://www.inc.or.kr/" target="_blank"><img alt="인터넷신문위원회" src="/data/skin/layout/1/m01/images/footer/20170214_InternetBanner_Tail.jpg"/></a>
#  </div>
#  <div class="powered">
#  <a href="http://www.kpf.or.kr/" target="_blank"><img alt="powered by 한국언론진흥재단" src="/data/skin/layout/1/m01/images/footer/powered.png"/></a>
#  </div>
#  </div>, <div class="logo">
#  <a href="/" onfocus="blur()" target="_top"><img alt="로고" height="38" src="/data/design/logo/taillogo_20161215213757.jpg" width="149"/></a>
#  </div>, <div class="add">
#              ㈜에너지경제신문사(제호:에너지경제) ｜ 등록번호:서울아02241 ｜ 등록일자:2012.08.30<br/>
#  발행인 : 송용희 ｜ 편집인 : 임정효 ｜ 서울특별시 중구 새문안로 26, 청양빌딩 5층<br/>
#  발행일자 : 1989.05.26 ｜ 대표전화 : 02)850-0114 ｜ 팩스 : 02)867-0453 <br/>
#  청소년보호책임자:박성준<br/>
#  <br/>
#  Mail to : ekn@ekn.kr<br/>
#  Copyright © 2013 에너지경제신문. All rights reserved.
#              </div>, <div class="internet">
#  <a href="https://www.inc.or.kr/" target="_blank"><img alt="인터넷신문위원회" src="/data/skin/layout/1/m01/images/footer/20170214_InternetBanner_Tail.jpg"/></a>
#  </div>, <div class="powered">
#  <a href="http://www.kpf.or.kr/" target="_blank"><img alt="powered by 한국언론진흥재단" src="/data/skin/layout/1/m01/images/footer/powered.png"/></a>
#  </div>, <div class="mobile_go">모바일 보기</div>, <div style="display:inline;">
#  <img alt="" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/856690710/?guid=ON&amp;script=0" style="border-style:none;" width="1"/>
#  </div>, <div style="margin-top:10px;">
#  <!------온라인뉴스2팀 : 2138 일경우 기본 배너 삭제. 본인것만 넣기-------->
#  </div>, <div style="height:100px;"></div>]

# %%
news=[]
for link in news_list["link"]:
    print(link)
    url = download(link)
    dom = BeautifulSoup(url.text,"lxml")
    for css in css_codes:
        if dom.select(css):
            print(css)
            news+=[[_.text for _ in dom.select(css)]]
# Out:
# http://v.media.daum.net/v/20190417143329712?f=o
# https://cp.news.search.daum.net/p/79811253
# http://v.media.daum.net/v/20190520103300854?f=o
# https://cp.news.search.daum.net/p/78557066
# http://v.media.daum.net/v/20190512104533601?f=o
# http://v.media.daum.net/v/20190508135613655?f=o
# https://cp.news.search.daum.net/p/79756321
# http://v.media.daum.net/v/20190516100024327?f=o
# http://v.media.daum.net/v/20190518110204069?f=o
# https://cp.news.search.daum.net/p/79756125
# #textinput p
# https://cp.news.search.daum.net/p/77344479
# https://cp.news.search.daum.net/p/79002479
# http://v.media.daum.net/v/20190513084804549?f=o
# http://v.media.daum.net/v/20190515113001532?f=o
# http://v.media.daum.net/v/20190513104002038?f=o
# #articleBody p
# https://cp.news.search.daum.net/p/79640291
# https://cp.news.search.daum.net/p/79739243
# https://cp.news.search.daum.net/p/79635632
# https://cp.news.search.daum.net/p/79743199
# http://v.media.daum.net/v/20190322040617333?f=o
# https://cp.news.search.daum.net/p/78844887
# https://cp.news.search.daum.net/p/79499140
# https://cp.news.search.daum.net/p/78816655
# https://cp.news.search.daum.net/p/79801669
# https://cp.news.search.daum.net/p/79477288
# tbody b
# https://cp.news.search.daum.net/p/79655392
# http://v.media.daum.net/v/20190418171549209?f=o
# https://cp.news.search.daum.net/p/79424938
# https://cp.news.search.daum.net/p/79620058
# https://cp.news.search.daum.net/p/79412924
# http://v.media.daum.net/v/20190328170122630?f=o
# https://cp.news.search.daum.net/p/77565139

# %% [markdown]
# ## 키워드 분석

# %%
from collections import Counter
from nltk import Text
from nltk.tokenize import sent_tokenize, word_tokenize, TweetTokenizer
from nltk.corpus import gutenberg
import os
import matplotlib.pyplot as plt
from math import log 
import re
from konlpy.tag import Okt
from konlpy.tag import Kkma # JVM 에서 가져오는 거라서 한번만 돌리는게 좋음
from konlpy.corpus import kolaw,kobill
from downloads import *
from get_corpus import *
from string import punctuation
from NLP import *

# %%
okt = Kkma()
q2_token = okt.pos(q)
query_list = [okt.pos(q)[0][0], okt.pos(q2)[0][0]]

# %%
find_keyword = [_.strip() for artcl in news for sen in artcl for _ in sen.split(".") if q2 in _ ]

# %%
query_list
# Out:
# ['삼성생명', '디지털']

# %%
pattern=re.compile("^NN|OL")

# %%
freq=FreqDist([_ for keyword in find_keyword for _ in okt.pos(keyword) if pattern.search(_[1]) and _[0] not in query_list and len(_[0])>1])

# %%
query_list
# Out:
# ['삼성생명', '디지털']

# %%
x=np.random.sample(len(freq))
y=np.random.sample(len(freq))

# %%
mean_freq=np.array(list(map(int,freq.values()))).mean()

# %%
plt.rcParams.update({'font.size': 10, 'figure.figsize':(12,8)})

# %%
freq
# Out:
# FreqDist({('원광', 'NNG'): 12, ('교수', 'NNG'): 8, ('수학', 'NNG'): 6, ('학과', 'NNG'): 4, ('사회', 'NNG'): 4, ('강연', 'NNG'): 4, ('대학교', 'NNG'): 4, ('클라우드', 'NNG'): 4, ('포럼', 'NNG'): 4, ('동양', 'NNG'): 4, ...})

# %%
freq[freq.max()]//3
# Out:
# 4

# %%
freq
# Out:
# FreqDist({('원광', 'NNG'): 12, ('교수', 'NNG'): 8, ('수학', 'NNG'): 6, ('학과', 'NNG'): 4, ('사회', 'NNG'): 4, ('강연', 'NNG'): 4, ('대학교', 'NNG'): 4, ('클라우드', 'NNG'): 4, ('포럼', 'NNG'): 4, ('동양', 'NNG'): 4, ...})

# %%
ax=sns.scatterplot(x,y,s=list(map(lambda e: e**3,freq.values())),alpha=0.5)
for key,value in enumerate(freq):
    if freq[value]>mean_freq:
        ax.text(x[key], y[key], value[0], horizontalalignment='left', size='medium', color='black', weight='semibold')

# %% [markdown]
# ## 특이한 단어를 뽑아낼 필요성을 느낌 : TF-IDF 미리하기

# %%
import pickle

# %%
with open('Tagged_news.pickle', 'rb') as f:
    data = pickle.load(f) # 단 한줄씩 읽어옴

# %%
normal_words = [__ for _ in data for __ in _ if pattern.search(__[1])]

# %%
normal_dist = FreqDist(normal_words)

# %%
tfidf_dict = FreqDist()
for key in freq.keys():
    if key in normal_dist.keys():
        tfidf_dict[key] = freq.get(key)/normal_dist.get(key)
    else:
        tfidf_dict[key] = freq[key]

# %%
ax = sns.scatterplot(x,y,s = list(map(lambda e: e**3,freq.values())),alpha = 0.5)
for key,value in enumerate(freq):
    if freq[value]>mean_freq:
        ax.text(x[key], y[key], value[0], horizontalalignment = 'left', size = 'medium', color = 'black', weight = 'semibold', )

# %% [markdown]
# ## 자기 자신은 빼야 함

# %%
"skt"
# Out:
# 'skt'
