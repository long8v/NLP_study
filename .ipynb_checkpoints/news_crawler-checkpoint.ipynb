# %% [markdown]
# # 지원동기 대신 써주는 프로그램

# %%
from bs4 import BeautifulSoup
from downloads import *
import requests
import time
import urllib
import os
from nltk.probability import FreqDist
from NLP import * 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib 
import matplotlib.pyplot as plt
import re
import matplotlib.font_manager as fm
import ngram
font_setting()

# %% [markdown]
# # Input

# %%
q=input("지원하시는 회사의 이름을 기재해주세요\t")
q2=input("지원하는 회사의 직무를 기재해주세요\t")
try:
    p=int(input("몇 페이지까지 검색할까요?\t\t"))
except:
    p=10
q3=input("공고에 직무에 대한 설명이 있다면 키워드 중심으로 같이 써주세요(없을 시 공란으로 두세요)\t")

# %%
naver=BeautifulSoup(download("https://search.naver.com/search.naver?",params={"query":q}).text,"lxml")
company_official_name=naver.select_one(".sp_company .main_title").text
company_name=[_.text for _ in naver.select(".nsite dt a")][0]
company_link=[_.text for _ in naver.select(".nsite dt a")][1].replace("www.","").replace(".com","")

# %%
company_official_name,company_name
# Out:
# ('디자이노블', 'LS산전')

# %%
print("{0}에 입사하게 된다면 최고의 {1} 전문가가 되도록 언제나 노력하겠습니다".format(company_official_name,q2))
# Out:
# 디자이노블에 입사하게 된다면 최고의   전문가가 되도록 언제나 노력하겠습니다

# %% [markdown]
# # Crawling

# %%
news_list=[]
for page in range(1,p+1):
    url=download("https://search.daum.net/search",params={"w":"news","q":q+" "+q2,"cluster":"y","p":str(page)})
    dom=BeautifulSoup(url.text,"lxml")
    news_list+=[(_["href"], _.text) for _ in dom.select("article .wrap_tit.mg_tit a")]

# %%
news_list
# Out:
# [('http://v.media.daum.net/v/20190328180320968?f=o',
#   '[부고]김동현(LS산전 최고재무책임자·상무)씨 모친상'),
#  ('http://v.media.daum.net/v/20190513104802402?f=o',
#   '[ET투자뉴스]LS산전_상장주식수 대비 거래량은 0.31%로 적정수준'),
#  ('https://cp.news.search.daum.net/p/77392194',
#   "[더벨]LS산전, 몰라보게 달라진 재무구조…올해도 '맑음'"),
#  ('https://cp.news.search.daum.net/p/79095436',
#   '[신한금융투자] LS산전 - 1분기 어닝쇼크·하반기 설비투자로 점진...'),
#  ('http://v.media.daum.net/v/20190521131007716?f=o',
#   '[ET투자뉴스]대덕전자_거래비중 기관 23.54%, 외국인 19.41%'),
#  ('http://v.media.daum.net/v/20190520095204133?f=o',
#   '[ET투자뉴스]LG이노텍_상장주식수 대비 거래량은 0.68%로 적정수준'),
#  ('https://cp.news.search.daum.net/p/79022220', 'LS산전, 주력부문 부진에 오너 역점사업도 삐걱'),
#  ('https://cp.news.search.daum.net/p/79012182',
#   '[공시봇] LS산전, 1Q 연결 영업이익 287억원 전년 대비 48.27% 감소'),
#  ('https://cp.news.search.daum.net/p/79733579',
#   '[민간기업 일자리 정보+] 케이티하이텔주식회사, 한국석유공사, (주...'),
#  ('https://cp.news.search.daum.net/p/79754336', '1분기 코스피 상장사 순익 39% 감소'),
#  ('http://v.media.daum.net/v/20190506170300016?f=o',
#   "정규직 지름길..이랜드·LG상사 '채용연계' 인턴 노려라"),
#  ('http://v.media.daum.net/v/20190403153901270?f=o',
#   "[대한민국 100대 CEO]구자균 LS산전 회장 | ESS로 신난 '스마트그리..."),
#  ('http://v.media.daum.net/v/20190403145204992?f=o',
#   '[ET투자뉴스]LS산전_거래비중 기관 29.72%, 외국인 24%'),
#  ('http://v.media.daum.net/v/20190404133004557?f=o',
#   '[ET투자뉴스]LS산전_상장주식수 대비 거래량은 0.33%로 적정수준'),
#  ('https://cp.news.search.daum.net/p/78478633', '(동반성장②)LS산전'),
#  ('http://v.media.daum.net/v/20190430040604038?f=o',
#   "[상생경영] LS, 시중은행과 '상생파트너론' 조성..협력사에 대기업 ..."),
#  ('http://v.media.daum.net/v/20190502132604064?f=o',
#   '[ET투자뉴스]LG이노텍_기관과 개인은 순매도, 외국인은 순매수(한달...'),
#  ('https://cp.news.search.daum.net/p/78155613',
#   '[더벨]LS산전·엠트론, 개발비 손상차손 매년 수십억 발생'),
#  ('https://cp.news.search.daum.net/p/79236572',
#   '[민간기업 일자리 정보+] 주식회사 카카오, 현대자동차(주), 한국석...'),
#  ('http://v.media.daum.net/v/20190422125904547?f=o',
#   '[ET투자뉴스]LG이노텍_상장주식수 대비 거래량은 0.81%로 적정수준'),
#  ('http://v.media.daum.net/v/20190311124204899?f=o',
#   '[ET투자뉴스]LS산전_거래비중 기관 26.58%, 외국인 24.63%'),
#  ('http://v.media.daum.net/v/20190329100004956?f=o',
#   '[부고종합] 이철씨(희망래일 이사장) 장인상 외'),
#  ('https://cp.news.search.daum.net/p/77755734',
#   'LS산전, ‘독립성 결여’ 사외이사 빈축..‘김앤장 고문’ 오정규에...'),
#  ('http://v.media.daum.net/v/20190329042152311?f=o',
#   '[부음] 하두봉 대한민국학술원 회원 별세 외'),
#  ('http://v.media.daum.net/v/20190328185603184?f=o', '3월 29일 궂긴 소식'),
#  ('http://v.media.daum.net/v/20190328174502330?f=o',
#   '[부고] 김규일 아이마켓코리아 대표 별세 外'),
#  ('http://v.media.daum.net/v/20190328200000480?f=o', '[부음] 민병옥씨 별세'),
#  ('https://cp.news.search.daum.net/p/78978566',
#   '[민간기업 일자리 정보+] (주)케이씨씨건설, (주)넥슨코리아, 엔에...'),
#  ('https://cp.news.search.daum.net/p/79168630',
#   '[오늘이슈] 아시아나항공 ‘희망퇴직’ 받는다, 한중일 통화스와프 ...'),
#  ('http://v.media.daum.net/v/20190415162902570?f=o',
#   'LS, 수출 중소기업에 특허기술 무상 지원'),
#  ('https://cp.news.search.daum.net/p/78911640',
#   '[민간기업 일자리 정보+] 주식회사 카카오, (주)케이씨씨건설, 메인...'),
#  ('http://v.media.daum.net/v/20190220133330821?f=o',
#   '구자균 LS산전 회장, 산기협 신임 회장 선임'),
#  ('http://v.media.daum.net/v/20190410150005540?f=o',
#   '[ET투자뉴스]대덕전자_거래비중 기관 23.67%, 외국인 33.01%'),
#  ('http://v.media.daum.net/v/20190412090103307?f=o',
#   '[이종락의 기업인맥 대해부](63) 오너 4세 경영시대를 연 박정원 두...'),
#  ('https://cp.news.search.daum.net/p/78808340',
#   '[장 마감 후 공시] HDC, 2천억 규모 주택재건축사업 시공사 선정外'),
#  ('http://v.media.daum.net/v/20190220110202593?f=o',
#   '[ET투자뉴스]LS산전_상장주식수 대비 거래량은 0.34%로 적정수준'),
#  ('http://v.media.daum.net/v/20190220141738491?f=o',
#   "韓산업기술진흥협 새 회장에 '구자균 LS산전 회장'"),
#  ('http://v.media.daum.net/v/20190220130008898?f=o',
#   '구자균 LS산전 회장, 한국산업기술진흥협회장 취임'),
#  ('http://v.media.daum.net/v/20190215115404642?f=o',
#   '[ET투자뉴스]LS산전_거래비중 기관 29.7%, 외국인 31.24%'),
#  ('https://cp.news.search.daum.net/p/77770571', '[부음] 김동현 모친'),
#  ('http://v.media.daum.net/v/20190403110805981?f=o',
#   '[ET투자뉴스]LG이노텍_외국인/기관 순매수, 개인은 순매도(한달누적)'),
#  ('https://cp.news.search.daum.net/p/78398861',
#   '[민간기업 일자리 정보+] 주식회사 카카오, (주)넥슨코리아, NHN한...'),
#  ('http://v.media.daum.net/v/20160125175506573?f=o', '"LS산전 재무상황 안정적"'),
#  ('https://cp.news.search.daum.net/p/75641922',
#   'LS산전, 작년 매출 2조4850억 원 ‘사상 최대’…전년비 6%↑'),
#  ('http://v.media.daum.net/v/20190326113105745?f=o',
#   '[ET투자뉴스]대덕전자_거래비중 기관 23.22%, 외국인 33.8%'),
#  ('https://cp.news.search.daum.net/p/76341828',
#   '구자균 LS산전 회장 "기술혁신 주체간 협력 플랫폼 추진하겠다"'),
#  ('https://cp.news.search.daum.net/p/76007007',
#   "[더벨]LS산전, 역대급 현금 보유…전력 인프라 사업 ‘성장'"),
#  ('http://v.media.daum.net/v/20190116095003889?f=o',
#   '[ET투자뉴스]LS산전_거래비중 기관 32.13%, 외국인 26.8%'),
#  ('https://cp.news.search.daum.net/p/76340987', '산업기술진흥회, 새 수장으로 구자균 LS산전 회장'),
#  ('http://v.media.daum.net/v/20190320134902913?f=o',
#   '[ET투자뉴스]일진머티리얼_거래비중 기관 17.08%, 외국인 17.81%'),
#  ('https://cp.news.search.daum.net/p/77954495',
#   '[민간기업 일자리 정보+] 주식회사 카카오, 현대자동차(주), (주)한...'),
#  ('http://v.media.daum.net/v/20190318134203630?f=o',
#   '[ET투자뉴스]대덕전자_거래비중 기관 24.06%, 외국인 32.63%'),
#  ('http://v.media.daum.net/v/20190107120150962?f=o',
#   'LS산전, 전일 대비 약 4% 상승한 48,100원'),
#  ('http://v.media.daum.net/v/20190314141103703?f=o',
#   '[ET투자뉴스]LG이노텍_상장주식수 대비 거래량은 0.67%로 적정수준'),
#  ('http://v.media.daum.net/v/20190322040324234?f=o',
#   '[청년이 미래다] LS, 스마트팩토리로 생산효율 극대화..임직원 재교...'),
#  ('https://cp.news.search.daum.net/p/75853742',
#   '[NH투자증권] LS산전 - 4분기 컨센서스 소폭 하회·매수유지 목표가...'),
#  ('https://cp.news.search.daum.net/p/72782405',
#   "[더벨]LS산전, 전력기기·인프라 수주부진에 '주춤'"),
#  ('http://v.media.daum.net/v/20190227040306982?f=o',
#   '[상생경영] LS, 全계열사 펀드조성 팔 걷어..자금난 해소하고 이자 ...'),
#  ('http://v.media.daum.net/v/20190314155433898?f=o',
#   '수은, 100조 규모 이라크 재건시장 세미나..주요 건설사 참여'),
#  ('http://v.media.daum.net/v/20190307110703241?f=o',
#   '[ET투자뉴스]대덕전자_주가와 거래량은 보통, 투자심리는 약세'),
#  ('http://v.media.daum.net/v/20181210140304582?f=o',
#   'LS산전, 전일 대비 약 5% 하락한 50,800원'),
#  ('http://v.media.daum.net/v/20190225141427730?f=o',
#   "'용산 시대' 100일 맞은 구자열 LS그룹 회장의 도전"),
#  ('https://cp.news.search.daum.net/p/75638792',
#   '[실적속보] LS산전(연결), 2018/4Q 영업이익 317억원...전년비 35.25%'),
#  ('https://cp.news.search.daum.net/p/77723913',
#   '[주총] 이광우 LS 부회장 "강인한 기업 체질 만들겠다"'),
#  ('http://v.media.daum.net/v/20190228105903762?f=o',
#   '[ET투자뉴스]대덕전자_거래비중 기관 26.74%, 외국인 26.23%'),
#  ('http://v.media.daum.net/v/20181128151126225?f=o',
#   'LS산전, 전일 대비 약 3% 상승한 51,500원'),
#  ('http://v.media.daum.net/v/20190207104403748?f=o',
#   '[ET투자뉴스]일진머티리얼_주요 매물구간인 38,050원선이 지지대로 ...'),
#  ('http://v.media.daum.net/v/20190226164215397?f=o',
#   '"효성重 무보증회사채 신용등급 A·안정적..사업지위·수주잔고 괜...'),
#  ('http://v.media.daum.net/v/20181026180931379?f=o',
#   'LS산전, 3분기 영업익 526억원..전년比 5.01%↓'),
#  ('http://v.media.daum.net/v/20171025201949466?f=o',
#   "LS산전, 2차 협력사 위한 '재무·기술 지원' 확대"),
#  ('http://v.media.daum.net/v/20190221040013300?f=o',
#   '구자균 신임 산기협회장 "기업이 국가R&D 79%맡지만 정책수립 과정...'),
#  ('https://cp.news.search.daum.net/p/77254331',
#   '한국태양광산업협회, "중국 태양광 기업 홍보성 기사가 도 넘어"'),
#  ('http://v.media.daum.net/v/20181102130439769?f=o',
#   'LS산전, 전일 대비 약 4% 상승한 53,000원'),
#  ('http://v.media.daum.net/v/20181030110204829?f=o',
#   'LS산전, 전일 대비 약 -6% 하락한 47,150원'),
#  ('http://v.media.daum.net/v/20181029120105219?f=o',
#   'LS산전, -11% 하락.. 전일 보다 6,700원 내린 52,900원'),
#  ('http://v.media.daum.net/v/20180726131105128?f=o',
#   'LS산전 2분기 영업익 653억원..역대 최대'),
#  ('http://v.media.daum.net/v/20181023120133197?f=o',
#   'LS산전, 전일 대비 약 -3% 하락한 58,900원'),
#  ('http://v.media.daum.net/v/20181023131503210?f=o',
#   '[ET투자뉴스]LS산전_거래비중 기관 37.28%, 외국인 34.18%'),
#  ('https://cp.news.search.daum.net/p/69822596', "[더벨]LS산전, 백조로 거듭난 '스마트그리드'"),
#  ('http://v.media.daum.net/v/20181025095904484?f=o',
#   '[ET투자뉴스]LS산전_상장주식수 대비 거래량은 0.32%로 적정수준'),
#  ('http://v.media.daum.net/v/20181017092103517?f=o',
#   '[마켓인사이트]LS산전 회사채 청약경쟁률 5.75대1'),
#  ('http://v.media.daum.net/v/20181012092202996?f=o',
#   '[ET투자뉴스]LS산전_거래비중 기관 36.99%, 외국인 37.04%'),
#  ('http://v.media.daum.net/v/20180726112844323?f=o',
#   "LS산전 상반기 실적 역대 최대..스마트에너지 부문 '흑전'"),
#  ('http://v.media.daum.net/v/20190130131004303?f=o',
#   '[ET투자뉴스]대덕전자_거래비중 기관 24.3%, 외국인 21.34%'),
#  ('https://cp.news.search.daum.net/p/76847334', '효성중공업 사업포트폴리오, 차입금 부담 이겨내나'),
#  ('https://cp.news.search.daum.net/p/76436911', '[2월3주차] 비즈니스피플 주간 임원인사 동향'),
#  ('http://v.media.daum.net/v/20180528153517041?f=o',
#   '[fnRASSI]LS산전(010120), 52주 신고가..9.95% ↑'),
#  ('http://v.media.daum.net/v/20180726104811414?f=o',
#   'LS산전 2분기 영업익 653억원..49% 증가'),
#  ('http://v.media.daum.net/v/20180420113542508?f=o',
#   '[fnRASSI]LS산전, 2.6% 오르며 거래량 증가'),
#  ('https://cp.news.search.daum.net/p/72422878',
#   'LS산전, 3분기 영업이익 526억원…전년 동기 대비 5.01%↓'),
#  ('http://v.media.daum.net/v/20180905100149972?f=o',
#   'LS산전, 전일 대비 약 3% 상승한 76,100원'),
#  ('https://cp.news.search.daum.net/p/76343399', '산기협, 구자균 신임 회장 선임'),
#  ('http://v.media.daum.net/v/20180904120108626?f=o',
#   'LS산전, 전일 대비 약 5% 상승한 74,200원'),
#  ('http://v.media.daum.net/v/20180906115505655?f=o',
#   '[ET투자뉴스]LS산전_거래비중 기관 39.54%, 외국인 20.87%'),
#  ('http://v.media.daum.net/v/20190130082332572?f=o', '장 마감 후 주요 공시-29일'),
#  ('http://v.media.daum.net/v/20190122092905255?f=o',
#   '[ET투자뉴스]일진머티리얼_상장주식수 대비 거래량은 0.94%로 적정수준'),
#  ('https://cp.news.search.daum.net/p/74012646',
#   '[NH투자증권]LS산전-보유유지 목표가 8만5000원'),
#  ('http://v.media.daum.net/v/20180913164503477?f=o',
#   "충북교육청·LS산전, 공사대금 등 추석 전 지급 '호응'"),
#  ('http://v.media.daum.net/v/20180726104738373?f=o',
#   'LS산전, 2Q 영업익 653억..전년비 49%↑'),
#  ('http://v.media.daum.net/v/20180423104009471?f=o',
#   '[fnRASSI]LS산전(010120), 52주 신고가..9.55% ↑')]

# %%
title=[title for link,title in news_list]

# %%
len(title)
# Out:
# 100

# %% [markdown]
# ### clean_title : 사용자 함수 만듦. 회사명과 [ ... ] 내역 지워줌

# %%
def clean_title(title,q):
    if q in title:
        title = title.replace(q,"")
    pattern = re.compile("\[.*\]")
    if pattern.search(title):
        title = pattern.sub("",title)
#         print(title)
    return title

# %% [markdown]
# ## find similar news using hamming distance

# %%
title=[title for link,title in news_list]
dist=[]
import textdistance
for i in range(len(title)):
    for _ in title[i:]:
        dist=textdistance.hamming.normalized_similarity(clean_title(_,q),clean_title(_,q))
        print(dist)
        if dist>0 and dist<1:
            print(title[i],dist,_)
            title[i]=np.nan

# textdistance.hamming('text', 'test')
# textdistance.hamming.normalized_similarity('text', 'test')
# textdistance.hamming('arrow', 'arow')textdistance.hamming.normalized_similarity('arrow', 'arow')

# %%
news_list=pd.DataFrame({"title":title,"link":[link for link,_ in news_list]}).dropna().reset_index().drop("index",1)

# %%
# for link, title in news_list:
#     url = download(link)
#     dom = BeautifulSoup(url.text,"lxml")
#     if dom.select("#articletxt"): # 한국 경제
#         print([_.text for _ in dom.select("#articletxt")])
#     elif dom.select("#articleBody p"):# 아이뉴스 
#         print(dom.select("#articleBody p"))
#     elif dom.select("#divNewsContent"):
#         print([_.text for _ in dom.select("#divNewsContent")])
#     elif dom.select("#articleText"):
#         print([_.text for _ in dom.select("#articleText")]) # 헤럴드경제
#     elif dom.select("#articleBody"):
#         print([_.text for _ in dom.select("#articleBody")]) # 전자신문

# %% [markdown]
# ## 링크 타고들어가서 뉴스 가져오기 : re사용

# %%
css_codes = ["[class*=['news']]"]

# %%
css_codes = ["[class*='news']","[class*='body']","[class*='article']"]

# %%
# news=[]
# for link,title in news_list:
#     print(link)
#     url = download(link)
#     dom = BeautifulSoup(url.text,"lxml")
#     for css in css_codes:
#         if dom.select(css):
#             print(css)
#             news+=[[_.text for _ in dom.select(css)]]
#             break

# %%
news = []
for link in news_list["link"]:
    url = download(link)
    dom = BeautifulSoup(url.text,"lxml")
    for css in css_codes:
        if dom.select(css):
            news += [[_.text for _ in dom.select(css)]]
            break

# %% [markdown]
# # get keyword

# %%
from collections import Counter
from nltk import Text
from nltk.tokenize import sent_tokenize, word_tokenize, TweetTokenizer
from nltk.corpus import gutenberg
import os
import matplotlib.pyplot as plt
from math import log 
import re
from konlpy.tag import Okt
from konlpy.tag import Kkma # JVM 에서 가져오는 거라서 한번만 돌리는게 좋음
from konlpy.corpus import kolaw,kobill
from downloads import *
from get_corpus import *
from string import punctuation
from NLP import *

# %%
okt = Kkma()
q2_token = okt.pos(q)
query_list = [okt.pos(q)[0][0], okt.pos(q2)[0][0]]

# %%
find_keyword = [_.strip() for artcl in news for sen in artcl for _ in sen.split(".") if q2 in _ ]

# %%
query_list
# Out:
# ['ls', '재무']

# %% [markdown]
# ## keyword cleansing : 그룹사, 다른이름 빼기

# %%
def split_sub(name):
    pttn=re.compile("[A-z]+")
    if pttn.search(name):
        return pttn.search(name)[0],pttn.sub("",name)

# %%
split_sub(company_official_name)
# Out:
# ('LS', '산전')

# %%
query_list+=[company_official_name,company_name,company_link,*split_sub(company_official_name),*split_sub(company_name)]

# %%
query_list
# Out:
# ['ls', '재무', 'LS산전', 'LS산전', 'lsis/ko', 'LS', '산전', 'LS', '산전']

# %%
for _ in range(2,len(q)):
    query_list+=ngram.umjeol(q,_)

# %%
query_list=[_.lower() for _ in query_list]

# %%
query_list=[_ for q in query_list for _ in q.split(" ")]

# %%
query_list
# Out:
# ['ls',
#  '재무',
#  'ls산전',
#  'ls산전',
#  'lsis/ko',
#  'ls',
#  '산전',
#  'ls',
#  '산전',
#  'ls',
#  's산',
#  '산전',
#  'ls산',
#  's산전']

# %% [markdown]
# ## find keyword  : preprocessing

# %%
find_keyword=[_.lower() for _ in find_keyword]

# %%
pattern=re.compile("(^NN)|OL")

# %%
freq=FreqDist([_ for keyword in find_keyword for _ in okt.pos(keyword) if _[0] not in query_list])

# %%
freq=FreqDist([_ for keyword in find_keyword for _ in okt.pos(keyword) if _[0] not in query_list and len(_[0])>1 and pattern.search(_[1])])

# %%
freq.plot()

# %% [markdown]
# # 시각화

# %%
plt.rcParams.update({'font.size': 10, 'figure.figsize':(14,12)})

# %%
# x=np.random.sample(len(freq))
# y=np.random.sample(len(freq))
# mean_freq=np.array(list(map(int,freq.values()))).mean()
# ax=sns.scatterplot(x,y,s=list(map(lambda e: e**2,freq.values())),alpha=0.5)
# for key,value in enumerate(freq):
#     if freq[value]>mean_freq:
#         ax.text(x[key], y[key], value[0], horizontalalignment='left', size='medium', color='black', weight='semibold')

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading https://files.pythonhosted.org/packages/23/4e/1254d26ce5d36facdcbb5820e7e434328aed68e99938c75c9d4e2fee5efb/wordcloud-1.5.0-cp37-cp37m-win_amd64.whl (153kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\user\anaconda3\lib\site-packages (from wordcloud) (1.16.2)
# Requirement already satisfied: pillow in c:\users\user\anaconda3\lib\site-packages (from wordcloud) (5.4.1)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.5.0

# %%
from wordcloud import WordCloud

# %%
# for_cld = FreqDist([_[0] for keyword in find_keyword for _ in okt.pos(keyword) if pattern.search(_[1]) and _[0] not in query_list and len(_[0])>1])
for_cld = FreqDist([_[0] for _ in freq])

# %%
"rpa" in [_[0] for _ in freq.keys()]
# Out:
# False

# %%
cld = WordCloud(font_path="c:/Windows/Fonts/malgun.ttf",width=600,height=400,background_color='white')
cld.generate_from_frequencies(for_cld).to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=600x400 at 0x1A3FFAFCF98>

# %% [markdown]
# ## 특이한 단어를 뽑아낼 필요성을 느낌 : TF-IDF 해보기

# %%
import pickle

# %%
with open('Tagged_news.pickle', 'rb') as f:
    data = pickle.load(f) # 단 한줄씩 읽어옴

# %%
normal_words = [__ for _ in data for __ in _ if pattern.search(__[1])]

# %%
normal_dist = FreqDist(normal_words)

# %%
tfidf_dict = FreqDist()
for key in freq.keys():
    if key in normal_dist.keys():
        tfidf_dict[key] = freq.get(key)/normal_dist.get(key)
    else:
        tfidf_dict[key] = freq[key]

# %%
mean_freq=np.array(list(map(int,tfidf_dict.values()))).mean()

# %%
freq
# Out:
# FreqDist({('분석', 'NNG'): 104, ('주가', 'NNG'): 68, ('기업', 'NNG'): 65, ('분기', 'NNG'): 54, ('가치', 'NNG'): 52, ('점수', 'NNG'): 49, ('예상', 'NNG'): 48, ('데이터', 'NNG'): 48, ('상장', 'NNG'): 45, ('결과', 'NNG'): 40, ...})

# %%
# ax = sns.scatterplot(x,y,s = list(map(lambda e: e**3,tfidf_dict.values())),alpha = 0.5)
# for key,value in enumerate(tfidf_dict):
#     if tfidf_dict[value]>mean_freq:
#         ax.text(x[key], y[key], value[0], horizontalalignment = 'left', size = 'medium', color = 'black', weight = 'semibold', )

# %% [markdown]
# 망함..

# %%
query_list
# Out:
# ['SKT',
#  'AI',
#  'sk',
#  'kt',
#  ['SK텔레콤'],
#  'SK telecom',
#  'www.sktelecom.com',
#  'SK텔레콤',
#  'SK telecom',
#  'www.sktelecom.com',
#  'SK텔레콤',
#  'SK telecom',
#  'www.sktelecom.com']
